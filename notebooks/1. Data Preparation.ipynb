# %% [markdown]
# # Post-Processing Amazon Textract with Location-Aware Transformers
#
# # Part 1: Introduction and Data Collection
#
# > *This notebook works well with the `Python 3 (Data Science)` kernel on SageMaker Studio*
#
# [**LayoutLM** (2019, Xu et al)](https://arxiv.org/abs/1912.13318) is a BERT-like language model architecture in which the *position embedding* inputs (usually encoding the position of each word/token in the input sequence, as detailed in [this paper](https://openreview.net/forum?id=onxoVA9FxMw)) are modified to encode the **absolute position of the word/token on a page**.
#
# Architectures like this enable us to build ML models which are aware of both *text content* and *page position*: especially useful for analyzing and post-processing OCR results from services like [Amazon Textract](https://aws.amazon.com/textract/), which returns both the detected text and the geometry of each word in the input document.
#
# Since LayoutLM is based on a standard multi-task text transformer architecture with customizations to the input processing layer, this approach could be generalized to a wide range of task types using both text and position information, like:
#
# - "Self-supervised" pre-training on Textracted but otherwise unlabelled documents
# - Document/page/sequence classification
# - Entity extraction (token/word classification)
# - Span extraction and extractive question answering
# - "Translation", generative question answering or other sequence generation
#
# Some of these use cases (notably pre-training, sequence classification and token/word classification) are already supported in the LayoutLM [implementation](https://huggingface.co/transformers/model_doc/layoutlm.html) provided in the popular open source [Hugging Face Transformers library](https://huggingface.co/transformers/model_doc/layoutlm.html).
#
# In this sample we'll review an example use case where Amazon Textract's [built-in functionality](https://aws.amazon.com/textract/features/) for extracting key-value "Forms" data and structured "Tables" data helps with some examples... But misses others due to the complexity of the document.
#
# This first notebook will focus on preparing and annotating data, before we move on to training, deploying, and integrating models in later notebooks.

# %% [markdown]
# ## Getting started: Dependencies and configuration
#
# First there are some additional libraries we need to install that aren't present in the SageMaker kernel environments by default:
#
# - [Amazon Textract Response Parser](https://github.com/aws-samples/amazon-textract-response-parser) is a helper for interpreting and navigating Amazon Textract result JSON.
# - The [SageMaker Studio Image Build CLI](https://github.com/aws-samples/sagemaker-studio-image-build-cli) is a tool for building customized container images and pushing to [Amazon ECR](https://aws.amazon.com/ecr/).
# - [SageMaker Python SDK](https://sagemaker.readthedocs.io/en/stable/) (installed by default in SageMaker already) must be version >=2.62 for the Hugging Face container versions used in notebook 2.

# %% [markdown]
# With the requried libraries installed, we're ready to import dependencies and set up some basic configuration including which [Amazon S3 bucket](https://docs.aws.amazon.com/AmazonS3/latest/userguide/UsingBucket.html) and folder/prefix data will be uploaded to.

# %%
# %load_ext autoreload
# %autoreload 3

# Python Built-Ins:
import json
import os
import random
import re
import shutil
from logging import getLogger
from zipfile import ZipFile

# External Dependencies:
import boto3  # AWS SDK for Python
import pandas as pd  # For tabular data analysis
import sagemaker  # High-level SDK for SageMaker

# Local Dependencies:
import util
from IPython.display import HTML  # To display rich content in notebook
from tqdm.notebook import tqdm  # Progress bars

try:
    import rich

    rich.reconfigure(force_terminal=True, force_jupyter=False)
    rich.pretty.install()
    print = rich.get_console().out
except:
    pass

logger = getLogger()

bucket_name = sagemaker.Session().default_bucket()
bucket_prefix = "textract-transformers/"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# For some sections below we'll need to reference resources created by the *[AWS CloudFormation](https://aws.amazon.com/cloudformation/) solution stack* you spun up earlier. If you didn't do this step yet, refer to the [README.md](../README.md) in the top level of the repository for instructions.
#
# The solution stack stores these useful variables in [AWS Systems Manager Parameter Store](https://docs.aws.amazon.com/systems-manager/latest/userguide/systems-manager-parameter-store.html) and we use the `util.project` utility module used below to fetch them. This is a transferable pattern you can use to connect from data science notebooks to deployed ML project resources in the cloud by project name/ID.
#
# ▶️ **Check** in the [CloudFormation Console](https://console.aws.amazon.com/cloudformation/home?#/stacks) that the `ProjectId` parameter for your OCR Pipeline Stack matches the default `ocr-transformers-demo` value below: Otherwise change the code below to match.
#
# > ⚠️ If you get an **AccessDeniedException** (ClientError) below, it's likely your [SageMaker execution role](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-roles.html) doesn't have the required `ssm:GetParameters` permission to look up the OCR pipeline stack parameters.
# >
# > To fix this, you can click your execution role in the [IAM Roles Console](https://console.aws.amazon.com/iamv2/home#/roles) and use the **Attach policies** button to attach the `PipelineDataSciencePolicy` created by the stack.

# %%
try:
    config = util.project.init("ocr-transformers-demo")
    print(config)
except Exception as e:
    try:
        print(f"Your SageMaker execution role is: {sagemaker.get_execution_role()}")
    except:
        print("Couldn't look up your SageMaker execution role")
    raise e
# Out:
# 2022-01-17 09:48:12,706 project [INFO] Working in project 'ocr-transformers-demo'
# <util.project.ProjectSession(
#   project_id=ocr-transformers-demo,
#   a2i_review_flow_arn_param=/ocr-transformers-demo/config/HumanReviewFlowArn,
#   entity_config_param=/ocr-transformers-demo/config/EntityConfiguration,
#   sagemaker_endpoint_name_param=/ocr-transformers-demo/config/SageMakerEndpointName,
#   a2i_execution_role_arn=arn:aws:iam::111122223333:role/OCRPipelineDemo-ProcessingPipelineReviewStepProces-17SOGS2NSBCM3,
#   pipeline_input_bucket_name=ocrpipelinedemo-pipelineinputbucket350ea1ae-f9kjwhjfj1bz,
#   pipeline_sfn_arn=arn:aws:states:ap-southeast-1:111122223333:stateMachine:ProcessingPipelineProcessingPipelineStateMachine91667981-5A6DQRRzn6Kl,
#   plain_textract_sfn_arn=arn:aws:states:ap-southeast-1:111122223333:stateMachine:ProcessingPipelineOCRStepTextractStateMachine1970CD25-78JIbhatroBp,
#   pipeline_reviews_bucket_name=ocrpipelinedemo-processingpipelinehumanreviewsbuc-vszv3a21k5f2,
#   sm_image_build_role=OCRPipelineDemo-AnnotationInfraSMImageBuildRole8DB-1COB4NPSEFB73
# ) at 0x7fcf2a4e11b0>

# %% [markdown]
# ## Fetch the data
#
# For our example, we'll be exploring (a recent quarter's snapshot of) the [Credit card agreements database](https://www.consumerfinance.gov/credit-cards/agreements/) published by the United States' [Consumer Finance Protection Bureau](https://www.consumerfinance.gov/).
#
# This dataset includes specimen credit card agreement documents from providers across the US, and is interesting for our purposes because the documents are:
#
# - **Diverse** in formatting, as various providers present the required information in different ways
# - **Representative of commercial** documents - rather than, for example, academic papers which might have quite different tone and structure
# - **Complex** in structure, with common data points in theory (e.g. interest rates, fees, etc) - but a lot of nuances and differences between documents in practice.
#
# Below, we download a recent (approx. 750MB) archive from the dataset and extract the files (approx. 900MB uncompressed):

# %%
os.makedirs("data/raw", exist_ok=True)

# Fetch the example data:
# !wget -O data/CC_Agreements.zip https://files.consumerfinance.gov/a/assets/Credit_Card_Agreements_2020_Q4.zip

# OR insert your own commands here if downloading a custom dataset. For example if on S3:
# !aws s3 sync s3://{DOC-EXAMPLE-BUCKET}/my/folder ./data/raw

# OR upload files manually from your computer by drag & drop to the folder sidebar on the left
# Out:
# --2022-01-17 09:48:23--  https://files.consumerfinance.gov/a/assets/Credit_Card_Agreements_2020_Q4.zip
# Resolving files.consumerfinance.gov (files.consumerfinance.gov)... 13.226.3.97, 13.226.3.27, 13.226.3.12, ...
# Connecting to files.consumerfinance.gov (files.consumerfinance.gov)|13.226.3.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 764289046 (729M) [application/zip]
# Saving to: ‘data/CC_Agreements.zip’
#
# 100%[======================================>] 764,289,046 15.1MB/s   in 66s
#
# 2022-01-17 09:49:31 (11.0 MB/s) - ‘data/CC_Agreements.zip’ saved [764289046/764289046]

# %%
# Extract the example zip and list the files inside:
with ZipFile("data/CC_Agreements.zip", "r") as fzip:
    rel_filepaths_all = sorted(
        [f.filename for f in fzip.infolist() if not (f.is_dir() or "__MACOSX" in f.filename)]
    )
    print(f"Found {len(rel_filepaths_all)} files in archive")
    print("Extracting...")
    fzip.extractall("data/raw")

# OR otherwise populate rel_filepaths_all with the list of files, relative to data/raw
# For example if your files are already uncompressed:
# rel_filepaths_all = sorted(filter(
#     lambda f: not (f.startswith(".") or "/." in f), # (Exclude hidden dot-files)
#     [
#         os.path.join(currpath, name)[len("data/raw/"):]
#         for currpath, dirs, files in os.walk("data/raw")
#         for name in files
#     ]
# ))
# Out:
# Found 2542 files in archive
# Extracting...

# %%
# Filter down to supported document file types:
valid_file_types = {"jpeg", "jpg", "pdf", "png"}
rel_filepaths = sorted(
    [f for f in rel_filepaths_all if f.lower().rpartition(".")[2] in valid_file_types]
)

# Clean up unneeded files and remap if the folder became nested:
# (This is written specific to our sample data zip, but is unlikely to break most custom data)
original_root_items = os.listdir("data/raw")
if "__MACOSX" in original_root_items:
    shutil.rmtree("data/raw/__MACOSX")
if len(original_root_items) < 4:
    try:
        folder = next(f for f in original_root_items if f.startswith("Credit_Card_Agreements"))
        print(f"De-nesting folder '{folder}'...")
        for sub in os.listdir(f"data/raw/{folder}"):
            shutil.move(f"data/raw/{folder}/{sub}", f"data/raw/{sub}")
        rel_filepaths = [
            f[len(folder + "/") :] if f.startswith(folder + "/") else f for f in rel_filepaths
        ]
    except StopIteration:
        pass

# Show the final results:
print(f"Found {len(rel_filepaths)} valid files for OCR:\n")
print("\n".join(rel_filepaths[:5] + (["...more..."] if len(rel_filepaths) > 5 else [])))
# Out:
# De-nesting folder 'Credit_Card_Agreements_2020_Q4'...
# Found 2541 valid files for OCR:
#
# 121 Financial Credit Union/Visa Applicaton and Solicitation Disclosure.pdf
# 121 Financial Credit Union/Visa Credit Card Agreement.pdf
# 1st Advantage Federal Credit Union/Mastercard Consumer Agreement.pdf
# 1st Advantage Federal Credit Union/Mastercard Consumer Disclosure.pdf
# 1st Century Bank/Rewards Credit Card Cardholder Agreement.pdf
# ...more...

# %% [markdown]
# You can explore these documents in the `data/raw` folder from the file browser - or even pull them through to display inline here in the notebook:

# %%
HTML(
    '<iframe src="{}" width=100% height=600 type="application/pdf"></iframe>'.format(
        # Edit the below (e.g. 0, 1, 2) to see different documents:
        "data/raw/"
        + rel_filepaths[0]
    )
)
# Out:
# /home/ec2-user/.pyenv/versions/layoutlm-p310/lib/python3.10/site-packages/IPython/core/display.py:414: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="data/raw/121 Financial Credit Union/Visa Applicaton and Solicitation Disclosure.pdf" width=100% height=600 type="application/pdf"></iframe>

# %% [markdown]
# For multi-page documents like these PDFs, Amazon Textract [requires us](https://docs.aws.amazon.com/textract/latest/dg/async.html) to use the async APIs and pre-load the documents to S3.
#
# Therefore we'll upload the PDFs to use later:

# %%
raw_s3uri = f"s3://{bucket_name}/{bucket_prefix}data/raw"

# %%
print(f"Uploading raw PDFs to {raw_s3uri}...")
# !aws s3 sync --quiet data/raw $raw_s3uri
print("Done")
# Out:
# Uploading raw PDFs to s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/raw...
# Done

# %% [markdown]
# ## Defining the challenge
#
# We have our source documents, so what will we try to extract about them?
#
# There are many ways position-aware NLP models might be applied to OCR outputs: For example to generate structured summaries, provide translations, answer questions, or just classify the documents.
#
# A common requirement in document analytics and process automation though, is to extract particular **'fields' of interest**: Known attributes expected to be present in all/most of the documents, which would be interesting to compare between them.
#
# In this example we'll tackle this as an **entity detection** task **via word classification**:
#
# - Defining a list of field/entity types of interest
# - Classifying each `WORD` in the document to these types, using a Hugging Face [LayoutLMForTokenClassification](https://huggingface.co/transformers/model_doc/layoutlm.html#layoutlmfortokenclassification) model
# - ...And finally grouping individual words together (via simple rule-based post-processing) to detect the entities/fields
#
# Some **benefits** of this approach are:
#
# - Results are traceable all the way back to the detected word blocks from the OCR engine; rather than with a text generation method where the output of the model may not correspond 1:1 with detected word inputs.
# - Annotation effort is relatively minimal; since we only need to highlight the documents, rather than typing out custom corrections, answers, etc.
#
# Some **drawbacks** are:
#
# - Since it only tags detected words, this model will not be able to *intelligently correct OCR errors* or *standardize form* (e.g. of dates) like a text generation method could learn to.
# - Since the ML component only extends to word classification, we're still relying on (usually good, helped by Amazon Textract) rule-based heuristics to group same-type words together to detect multi-word entities.
#
# Below, we'll define the set of fields/entities to be detected and their configuration aspects:
#
# > ⚠️ **Warning:** Although you may **edit** the configuration below, you'll no longer be able to use the pre-annotated data sample we provide in `data/annotations` to accelerate model training (unless the classes are still defined in the same order, and labelled in a consistent way with the previous guidelines)

# %%
from util.postproc.config import FieldConfiguration

# For config API details, you can see the docs in the source file or run:
# help(FieldConfiguration)

fields = [
    # (To prevent human error, enter class_id=0 each time and update programmatically below)
    FieldConfiguration(
        0,
        "Agreement Effective Date",
        optional=True,
        select="first",
        annotation_guidance=(
            "<p>Avoid labeling extraneous dates which are not necessarily the effective date of "
            "the document: E.g. copyright dates/years, or other dates mentioned in text.</p> "
            "<p>Do not include unnecessary qualifiers e.g. 'from 2020/01/01'.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "APR - Introductory",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Use this class (instead of the others) for <em>ANY</em> case where the rate is "
            "offered for a fixed introductory period - regardless of interest rate subtype e.g. "
            "balance transfers, purchases, etc.</p> "
            "<p>Include the term of the introductory period in cases where it's directly listed "
            "(e.g. '20.00% for the first 6 months'). Try to minimize/exclude extraneous "
            "information about the offer (e.g. '20.00% for the first 6 months after account "
            "opening').</p> "
            "<p>'Prime rate + X%' mentions are acceptable and should be labeled.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "APR - Balance Transfers",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Use for interest rates which are specific to balance transfers.</p> "
            "<p>Avoid including extraneous information about the terms of balance transfers, or "
            "using for fixed-term introductory rates.</p> "
            "<p>'Prime rate + X%' mentions are acceptable and should be labeled.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "APR - Cash Advances",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Use for interest rates which are specific to cash advances.</p> "
            "<p>Avoid including extraneous information about the terms of cash advances, or using "
            "for fixed-term introductory rates.</p> "
            "<p>'Prime rate + X%' mentions are acceptable and should be labeled.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "APR - Purchases",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Use for interest rates which are specific to purchases.</p> "
            "<p>'Prime rate + X%' mentions are acceptable and should be labeled.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "APR - Penalty",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Use for penalty interest rates applied under certain conditions.</p> "
            "<p><em>Exclude</em> include information about the conditions under which the penalty "
            "rate comes into effect: Only include the interest rate which will be applied.</p> "
            "<p>'Prime rate + X%' mentions are acceptable and should be labeled.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "APR - General",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Use for interest rates which are general and not specifically tied to a "
            "particular transaction type e.g. purchases / balance transfers.</p> "
            "<p>Avoid using for fixed-term introductory rates.</p> "
            "<p>'Prime rate + X%' mentions are acceptable and should be labeled.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "APR - Other",
        optional=True,
        select="confidence",
        # TODO: Remove this class
        annotation_guidance=(
            "<p>Use only for interest rates which don't fall in to any other category (including "
            "general or introductory rates). You may not see any examples in the data.</p> "
            "<p>Avoid using for fixed-term introductory rates.</p> "
            "<p>'Prime rate + X%' mentions are acceptable and should be labeled.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Fee - Annual",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Include cases where the document explicitly indicates no fee e.g. 'None'</p> "
            "<p>Avoid any introductory terms e.g. '$0 for the first 6 months' or extraneous "
            "words: Label only the standard fee.</p> "
            "<p>Label only the annual amount of the fee, in cases where other breakdowns are "
            "specified: E.g. '$120', not '$10 per month ($120 per year)'.</p> "
        ),
    ),
    FieldConfiguration(
        0,
        "Fee - Balance Transfer",
        optional=True,
        select="confidence",
        annotation_guidance=(
            # TODO: Review
            "<p>Try to be concise and exclude extra terms where not necessary</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Fee - Late Payment",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Label only the fee, not the circumstances in which it is payable.</p> "
            "<p>Limits e.g. 'Up to $25' are acceptable (don't just label '$25').</p> "
            "<p>Do <em>NOT</em> include non-specific mentions of pass-throgh costs (e.g. 'legal "
            "costs', 'reasonable expenses', etc.) incurred in the general collections process.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Fee - Returned Payment",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Label only the fee, not the circumstances in which it is payable.</p> "
            "<p>Limits e.g. 'Up to $25' are acceptable (don't just label '$25').</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Fee - Foreign Transaction",
        optional=True,
        select="shortest",
        annotation_guidance=(
            "<p>Do <em>NOT</em> include explanations of how exchange rates are calculated or "
            "non-specific indications of margins between rates. <em>DO</em> include specific "
            "charges/margins with <em>brief</em> clarifying info where listed e.g. '3% of the US "
            "dollar amount'.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Fee - Other",
        ignore=True,
        annotation_guidance=(
            "<p>Common examples include: Minimum interest charge, cash advance fees, and "
            "overlimit fees.</p> "
            "<p>Do <em>NOT</em> include fixed-term introductory rates for fees (e.g. '$0 during "
            "the first year. After the first year...') - only the standard fees</p> "
            "<p><em>DO</em> include qualifying information on the amount and limits of the fee, "
            "e.g. '$5 or 5% of the amount of each transaction, whichever is the greater'.</p> "
            "<p>Do <em>NOT</em> include general information on the nature of the fee and "
            "circumstances under which it is applied: E.g. 'Cash advance fee' or 'If the amount "
            "of interest payable is...'</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Card Name",
        annotation_guidance=(
            "<p>Label instances of the brand name of specific card(s) offered by the provider "
            "under the agreement, e.g. 'Rewards Platinum Card'</p> "
            "<p>Include the ' Card' suffix where available, but also annotate instances without "
            "such as 'Rewards Platinum'</p> "
            "<p><em>Avoid</em> including the Provider Name (use the separate class for this) e.g. "
            "'AnyCompany Rewards Card' unless it's been substantially modified/abbreviated for "
            "the card name (e.g. 'AnyCo Rewards Card') or the company name is different from the "
            "Credit card provider (e.g. AnyBank offering a store credit card for AnyCompany)</p> "
            "<p>Do <em>NOT</em> include fixed-term introductory rates for fees (e.g. '$0 during "
            "the first year. After the first year...') - only the standard fees</p> "
            "<p><em>Avoid</em> labeling generic payment provider names e.g. 'VISA card' or "
            "'Mastercard', except in contexts where the provider clearly uses them as the brand "
            "name for the offered card (e.g. 'VISA Card' from 'AnyCompany VISA Card'.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Provider Address",
        optional=True,
        select="confidence",
        annotation_guidance=(
            "<p>Include department or 'attn:' lines where present (but not Provider Name where "
            "used at the start of an address e.g. 'AnyCompany; 100 Main Street...').</p> "
            "<p>Include zip/postcode where present.</p> "
            "<p><em>Avoid</em> labeling addresses for non-provider entities, such as watchdogs, "
            "market regulators, or independent agencies.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Provider Name",
        select="longest",
        annotation_guidance=(
            "<p>Label the name of the card provider: Including abbreviated mentions.</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Min Payment Calculation",
        ignore=True,
        annotation_guidance=(
            "<p>Label clauses describing how the minimum payment is calculated.</p> "
            "<p>Exclude lead-in e.g. 'The minimum payment is calculated as...' and label directly "
            "from e.g. 'the minimum of...'.</p> "
            "<p>Do <em>NOT</em> include clauses from related subjects e.g. how account balance is "
            "calculated</p>"
        ),
    ),
    FieldConfiguration(
        0,
        "Local Terms",
        ignore=True,
        annotation_guidance=(
            "<p>Label full terms specific to residents of certain states/countries, or applying "
            "only in particular jurisdictions.</p> "
            "<p><em>Include</em> the scope of where the terms apply e.g. 'Residents of GA and "
            "VA...'</p> "
            "<p><em>Include</em> locally-applicable interest rates, instead of annotating these "
            "with the 'APR - ' classes</p>"
        ),
    ),
]
for ix, cfg in enumerate(fields):
    cfg.class_id = ix

# Save the configuration to file:
with open("data/field-config.json", "w") as f:
    f.write(
        json.dumps(
            [cfg.to_dict() for cfg in fields],
            indent=2,
        )
    )

# %%
entity_classes = [f.name for f in fields]
print("\n".join(entity_classes))
# Out:
# Agreement Effective Date
# APR - Introductory
# APR - Balance Transfers
# APR - Cash Advances
# APR - Purchases
# APR - Penalty
# APR - General
# APR - Other
# Fee - Annual
# Fee - Balance Transfer
# Fee - Late Payment
# Fee - Returned Payment
# Fee - Foreign Transaction
# Fee - Other
# Card Name
# Provider Address
# Provider Name
# Min Payment Calculation
# Local Terms

# %% [markdown]
# ## Data collection
#
# To efficiently annotate training data for entity extraction on documents, we'll want to work **visually**: Highlighting matches, and perhaps also collecting manual transcription reviews - in case we'd like to extend the model later to support correcting text.
#
# [Amazon SageMaker Ground Truth](https://aws.amazon.com/sagemaker/groundtruth/) provides an out-of-the-box annotation UI [for bounding boxes](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-bounding-box.html) which will be useful for this: And can also be incorporated within [customized annotation UIs](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-custom-templates.html) via the [crowd-bounding-box](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-ui-template-crowd-bounding-box.html) element.
#
# However, at the time of writing, the bounding box annotation tool supports images but not PDFs.
#
# Therefore to prepare for data annotation we'll need to:
#
# - Run our documents through Amazon Textract
# - Extract individual page images from the PDFs to use through the annotation UI
# - Collate the page images and Textract results together, ready for annotation
#
# For a significantly sized corpus like this, we'd also benefit from filtering down the data a little - to save time and cost by Textracting and converting only the amount of data we'll need.

# %% [markdown]
# ### Filter a sample of the document set
#
# To limit down our input corpus, we'll:
#
# 1. Apply some basic filename-based rules to try and exclude the few Spanish-language documents in the corpus, since the pre-trained model we'll use later is for English only
# 2. Take a random (but reproducible) split of the first N documents
#
# > ⚠️ If you're using a custom dataset:
# >
# > - Remember to **delete the `data/annotations/augmentation-*` folders** before running this to avoid errors. This is because the `get_preannotated_filepaths()` function below automatically tries to include any already-annotated documents in the sample.
# > - The exclusion rules in `include_filename()` may not be relevant to you, so consider reviewing them.

# %%
N_DOCS_KEPT = 120


def include_filename(name: str) -> bool:
    """Filter out docs whose filenames suggest they're likely Spanish/non-English"""
    if not name:
        return name
    name_l = name.lower()
    if "spanish" in name_l:
        return False
    if re.search(r"espa[nñ]ol", name_l):
        return False
    if "tarjeta" in name_l or re.search(r"cr[eé]dito", name_l):
        return False
    if re.search(r"[\[\(]esp?[\]\)]", name_l):
        return False
    return True


def get_preannotated_filepaths(exclude_job_names=[]) -> list:
    """List out (alphabetically) the relative filepaths for which annotations are already exist"""
    filepaths = set()  # Protect against introducing duplicates
    for job_folder in os.listdir("data/annotations"):
        if job_folder in exclude_job_names:
            logger.info(f"Skipping excluded job {job_folder}")
            continue
        manifest_file = os.path.join(
            "data",
            "annotations",
            job_folder,
            "manifests",
            "output",
            "output.manifest",
        )
        if not os.path.isfile(manifest_file):
            if os.path.isdir(os.path.join("data", "annotations", job_folder)):
                logger.warning(f"Skipping job {job_folder}: No output manifest at {manifest_file}")
            continue
        with open(manifest_file, "r") as f:
            textract_s3keys = [
                json.loads(l)["textract-ref"][len("s3://") :].partition("/")[2] for l in f
            ]
            # S3 keys are like some/prefix/data/textracted/subfolders/file.pdf/consolidated.json
            # We want subfolders/file.pdf
            filepaths.update(
                [k.partition("data/textracted/")[2].rpartition("/")[0] for k in textract_s3keys]
            )
    return sorted(filepaths)


preannotated_filepaths = get_preannotated_filepaths()
if N_DOCS_KEPT < len(preannotated_filepaths):
    raise ValueError(
        "Existing annotations cannot be used for model training unless the target documents are "
        "Textracted. To proceed with fewer docs than have already been annotated, you'll need to "
        "`exclude_job_names` per the 'data/annotations' folder (e.g. ['augmentation-1']) AND "
        "remember to not include them in notebook 2 (model training). Alternatively, increase "
        f"your N_DOCS_KEPT. (Got {N_DOCS_KEPT} vs {len(preannotated_filepaths)} prev annotations)."
    )

# Forcibly including the pre-annotated docs *after* the shuffling ensures that the order of
# sampling new docs is independent of what/how many have been pre-annotated:
rel_filepaths_sample = list(filter(include_filename, rel_filepaths))
random.Random(1337).shuffle(rel_filepaths_sample)
rel_filepaths_sample = [f for f in rel_filepaths_sample if f not in preannotated_filepaths]
rel_filepaths_sample = sorted(
    preannotated_filepaths + rel_filepaths_sample[: N_DOCS_KEPT - len(preannotated_filepaths)]
)

print(f"Extracted random sample of {len(rel_filepaths_sample)} docs")
rel_filepaths_sample[:5] + ["..."]
# Out:
# Extracted random sample of 120 docs
#
# [
#     'American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure.pdf',
#     'American Express National Bank/American Express Gold Card Cardmember Agreement.pdf',
#     'American Express National Bank/American Express Green Card Cardmember Agreement.pdf',
#     'Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement.pdf',
#     'Associated Credit Union/Visa Credit Card Agreement and Disclosures.pdf',
#     '...'
# ]

# %% [markdown]
# ### Extract clean input images
#
# To annotate our documents with SageMaker Ground Truth image task UIs, we need **individual page images**, stripped of EXIF rotation metadata (because, at the time of writing, SMGT ignores this rotation for annotation consistency) and converted to compatible formats (since some browsers cannot render certain formats - such as TIFF).
#
# For large corpora this process of splitting PDFs and rotating and converting images may require significant resources, but is easy to parallelize.
#
# Therefore instead of pre-processing the raw documents here in the notebook, this is a good use case for a scalable [SageMaker Processing Job](https://docs.aws.amazon.com/sagemaker/latest/dg/processing-job.html).
#
# First, our processing job will require a base **container image** to work with. The PDF reading tools we use aren't installed by default in pre-built SageMaker containers and aren't `pip install`able, so below we use the [SageMaker Studio Image Build CLI](https://github.com/aws-samples/sagemaker-studio-image-build-cli) to build a customized image based on the SageMaker Scikit-Learn container and upload it to the [Amazon Elastic Container Registry (ECR)](https://aws.amazon.com/ecr/):

# %%
# Configurations:
ecr_repo_name = "sm-scikit-ocrtools"
ecr_image_tag = "pytorch-1.7-cpu"

base_image_uri = sagemaker.image_uris.retrieve(
    framework="pytorch",
    region=os.environ["CDK_DEFAULT_REGION"],
    instance_type="ml.c5.xlarge",  # (Just used to check whether GPUs/accelerators are used)
    py_version="py3",
    image_scope="training",
    version="1.7",
)

# Combine together into the final URI (not needed for the build, but used later in the notebook):
account_id = sagemaker.Session().account_id()
region = os.environ["CDK_DEFAULT_REGION"]
ecr_image_uri = f"{account_id}.dkr.ecr.{region}.amazonaws.com/{ecr_repo_name}:{ecr_image_tag}"
print(f"Will build to {ecr_image_uri}")
# Out:
# Will build to 111122223333.dkr.ecr.ap-southeast-1.amazonaws.com/sm-scikit-ocrtools:pytorch-1.7-cpu

# %%
#%%time
# (No need to re-run this cell if your image is already in ECR)

# Actually build & push the container image:
# !sm-docker build ./preproc \
    --repository {ecr_repo_name}:{ecr_image_tag} \
    --role {config.sm_image_build_role} \
    --build-arg BASE_IMAGE={base_image_uri}
# Out:
# Created ECR repository sm-scikit-ocrtools
# ....[Container] 2022/01/17 10:28:51 Waiting for agent ping
#
# [Container] 2022/01/17 10:28:52 Waiting for DOWNLOAD_SOURCE
# [Container] 2022/01/17 10:29:07 Phase is DOWNLOAD_SOURCE
# [Container] 2022/01/17 10:29:07 CODEBUILD_SRC_DIR=/codebuild/output/src386007609/src
# [Container] 2022/01/17 10:29:07 YAML location is /codebuild/output/src386007609/src/buildspec.yml
# [Container] 2022/01/17 10:29:07 Processing environment variables
# [Container] 2022/01/17 10:29:07 No runtime version selected in buildspec.
# [Container] 2022/01/17 10:29:07 Moving to directory /codebuild/output/src386007609/src
# [Container] 2022/01/17 10:29:07 Configuring ssm agent with target id: codebuild:860e1482-447c-4857-910e-836b0dbc3f60
# [Container] 2022/01/17 10:29:07 Successfully updated ssm agent configuration
# [Container] 2022/01/17 10:29:07 Registering with agent
# [Container] 2022/01/17 10:29:07 Phases found in YAML: 3
# [Container] 2022/01/17 10:29:07  PRE_BUILD: 9 commands
# [Container] 2022/01/17 10:29:07  BUILD: 4 commands
# [Container] 2022/01/17 10:29:07  POST_BUILD: 3 commands
# [Container] 2022/01/17 10:29:07 Phase complete: DOWNLOAD_SOURCE State: SUCCEEDED
# [Container] 2022/01/17 10:29:07 Phase context status code:  Message:
# [Container] 2022/01/17 10:29:07 Entering phase INSTALL
# [Container] 2022/01/17 10:29:07 Phase complete: INSTALL State: SUCCEEDED
# [Container] 2022/01/17 10:29:07 Phase context status code:  Message:
# [Container] 2022/01/17 10:29:07 Entering phase PRE_BUILD
# [Container] 2022/01/17 10:29:07 Running command echo Logging in to Amazon ECR...
# Logging in to Amazon ECR...
#
# [Container] 2022/01/17 10:29:07 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2022/01/17 10:29:13 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 763104351884)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2022/01/17 10:29:14 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 217643126080)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2022/01/17 10:29:14 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 727897471807)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2022/01/17 10:29:14 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 626614931356)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2022/01/17 10:29:15 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 683313688378)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2022/01/17 10:29:15 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 520713654638)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2022/01/17 10:29:16 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 462105765813)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2022/01/17 10:29:16 Phase complete: PRE_BUILD State: SUCCEEDED
# [Container] 2022/01/17 10:29:16 Phase context status code:  Message:
# [Container] 2022/01/17 10:29:16 Entering phase BUILD
# [Container] 2022/01/17 10:29:16 Running command echo Build started on `date`
# Build started on Mon Jan 17 10:29:16 UTC 2022
#
# [Container] 2022/01/17 10:29:16 Running command echo Building the Docker image...
# Building the Docker image...
#
# [Container] 2022/01/17 10:29:16 Running command docker build -t $IMAGE_REPO_NAME:$IMAGE_TAG ./preproc --build-arg BASE_IMAGE=763104351884.dkr.ecr.ap-southeast-1.amazonaws.com/pytorch-training:1.7-cpu-py3
# Sending build context to Docker daemon  15.87kB
# Step 1/3 : ARG BASE_IMAGE
# Step 2/3 : FROM ${BASE_IMAGE}
# 1.7-cpu-py3: Pulling from pytorch-training
# 4bbfd2c87b75: Pulling fs layer
# d2e110be24e1: Pulling fs layer
# 889a7173dcfe: Pulling fs layer
# 663e9d8a584c: Pulling fs layer
# 1a87ca8a6e6f: Pulling fs layer
# 06620b5dbfbc: Pulling fs layer
# 358ce265d058: Pulling fs layer
# 7f60eb8f301f: Pulling fs layer
# 4f292f6c375f: Pulling fs layer
# 4aa498b57d18: Pulling fs layer
# 54fd2b7026a0: Pulling fs layer
# c2e921eca274: Pulling fs layer
# e40337ad01db: Pulling fs layer
# 663e9d8a584c: Waiting
# 1a87ca8a6e6f: Waiting
# 06620b5dbfbc: Waiting
# 358ce265d058: Waiting
# 7f60eb8f301f: Waiting
# 4f292f6c375f: Waiting
# 4aa498b57d18: Waiting
# 54fd2b7026a0: Waiting
# c2e921eca274: Waiting
# e40337ad01db: Waiting
# d2e110be24e1: Verifying Checksum
# d2e110be24e1: Download complete
# 889a7173dcfe: Verifying Checksum
# 889a7173dcfe: Download complete
# 1a87ca8a6e6f: Verifying Checksum
# 1a87ca8a6e6f: Download complete
# 06620b5dbfbc: Download complete
# 358ce265d058: Verifying Checksum
# 358ce265d058: Download complete
# 4bbfd2c87b75: Verifying Checksum
# 4bbfd2c87b75: Download complete
# 4bbfd2c87b75: Pull complete
# d2e110be24e1: Pull complete
# 889a7173dcfe: Pull complete
# 663e9d8a584c: Verifying Checksum
# 663e9d8a584c: Download complete
# 4aa498b57d18: Verifying Checksum
# 4aa498b57d18: Download complete
# 54fd2b7026a0: Verifying Checksum
# 54fd2b7026a0: Download complete
# c2e921eca274: Verifying Checksum
# c2e921eca274: Download complete
# e40337ad01db: Verifying Checksum
# e40337ad01db: Download complete
# 4f292f6c375f: Verifying Checksum
# 4f292f6c375f: Download complete
# 7f60eb8f301f: Verifying Checksum
# 7f60eb8f301f: Download complete
# 663e9d8a584c: Pull complete
# 1a87ca8a6e6f: Pull complete
# 06620b5dbfbc: Pull complete
# 358ce265d058: Pull complete
# 7f60eb8f301f: Pull complete
# 4f292f6c375f: Pull complete
# 4aa498b57d18: Pull complete
# 54fd2b7026a0: Pull complete
# c2e921eca274: Pull complete
# e40337ad01db: Pull complete
# Digest: sha256:22de348a65a1f9894a06ed6629c1490d8ea2996eabe1f9c24eb94ba67e0a7bcd
# Status: Downloaded newer image for 763104351884.dkr.ecr.ap-southeast-1.amazonaws.com/pytorch-training:1.7-cpu-py3
#  ---> 736d92068a19
# Step 3/3 : RUN conda install -c conda-forge poppler -y   && pip install amazon-textract-response-parser pdf2image "Pillow>=8,<9"
#  ---> Running in 4183c37685f3
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - poppler
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            1_gnu          22 KB
#     c-ares-1.18.1              |       h7f8727e_0         114 KB
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     curl-7.78.0                |       h1ccaba5_0          94 KB
#     krb5-1.19.2                |       hcc1bbae_0         1.4 MB  conda-forge
#     libcurl-7.78.0             |       h0b77cf5_0         338 KB
#     libedit-3.1.20191231       |       he28a2e2_2         121 KB  conda-forge
#     libev-4.33                 |       h516909a_1         104 KB  conda-forge
#     libgcc-ng-9.3.0            |      h5101ec6_17         4.8 MB
#     libgomp-9.3.0              |      h5101ec6_17         311 KB
#     libnghttp2-1.43.0          |       h812cca2_0         808 KB  conda-forge
#     libssh2-1.9.0              |       h1ba5d50_1         269 KB
#     libstdcxx-ng-11.2.0        |      he4da1e4_11         4.2 MB  conda-forge
#     openjpeg-2.3.1             |       h58a6597_0         470 KB  conda-forge
#     openssl-1.1.1m             |       h7f8727e_0         2.5 MB
#     poppler-0.67.0             |       ha967d66_7         8.9 MB  conda-forge
#     poppler-data-0.4.11        |       hd8ed1ab_0         3.6 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        28.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   c-ares             pkgs/main/linux-64::c-ares-1.18.1-h7f8727e_0
#   curl               pkgs/main/linux-64::curl-7.78.0-h1ccaba5_0
#   krb5               conda-forge/linux-64::krb5-1.19.2-hcc1bbae_0
#   libcurl            pkgs/main/linux-64::libcurl-7.78.0-h0b77cf5_0
#   libedit            conda-forge/linux-64::libedit-3.1.20191231-he28a2e2_2
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_0
#   libssh2            pkgs/main/linux-64::libssh2-1.9.0-h1ba5d50_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.3.1-h58a6597_0
#   poppler            conda-forge/linux-64::poppler-0.67.0-ha967d66_7
#   poppler-data       conda-forge/noarch::poppler-data-0.4.11-hd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.4.13-~ --> conda-forge::ca-certificates-2021.10.8-ha878542_0
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 9.3.0-h5101ec6_17
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.1.0-hdf63c6~ --> conda-forge::libstdcxx-ng-11.2.0-he4da1e4_11
#   openssl                                 1.1.1k-h27cfd23_0 --> 1.1.1m-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# c-ares-1.18.1        | 114 KB    | ########## | 100%
# ca-certificates-2021 | 139 KB    | ########## | 100%
# poppler-data-0.4.11  | 3.6 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# openssl-1.1.1m       | 2.5 MB    | ########## | 100%
# libedit-3.1.20191231 | 121 KB    | ########## | 100%
# curl-7.78.0          | 94 KB     | ########## | 100%
# libstdcxx-ng-11.2.0  | 4.2 MB    | ########## | 100%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
# libssh2-1.9.0        | 269 KB    | ########## | 100%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
# libnghttp2-1.43.0    | 808 KB    | ########## | 100%
# krb5-1.19.2          | 1.4 MB    | ########## | 100%
# libev-4.33           | 104 KB    | ########## | 100%
# poppler-0.67.0       | 8.9 MB    | ########## | 100%
# openjpeg-2.3.1       | 470 KB    | ########## | 100%
# libcurl-7.78.0       | 338 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting amazon-textract-response-parser
#   Downloading amazon_textract_response_parser-0.1.24-py2.py3-none-any.whl (24 kB)
# Collecting pdf2image
#   Downloading pdf2image-1.16.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: Pillow<9,>=8 in /opt/conda/lib/python3.6/site-packages (8.2.0)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.6/site-packages (from amazon-textract-response-parser) (1.17.79)
# Collecting marshmallow==3.11.1
#   Downloading marshmallow-3.11.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: botocore<1.21.0,>=1.20.79 in /opt/conda/lib/python3.6/site-packages (from boto3->amazon-textract-response-parser) (1.20.79)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /opt/conda/lib/python3.6/site-packages (from boto3->amazon-textract-response-parser) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3->amazon-textract-response-parser) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.79->boto3->amazon-textract-response-parser) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.79->boto3->amazon-textract-response-parser) (1.26.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.79->boto3->amazon-textract-response-parser) (1.16.0)
# Installing collected packages: marshmallow, pdf2image, amazon-textract-response-parser
# Successfully installed amazon-textract-response-parser-0.1.24 marshmallow-3.11.1 pdf2image-1.16.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Removing intermediate container 4183c37685f3
#  ---> 0b439eab528a
# Successfully built 0b439eab528a
# Successfully tagged sm-scikit-ocrtools:pytorch-1.7-cpu
#
# [Container] 2022/01/17 10:31:08 Running command docker tag $IMAGE_REPO_NAME:$IMAGE_TAG $AWS_ACCOUNT_ID.dkr.ecr.$AWS_DEFAULT_REGION.amazonaws.com/$IMAGE_REPO_NAME:$IMAGE_TAG
#
# [Container] 2022/01/17 10:31:08 Phase complete: BUILD State: SUCCEEDED
# [Container] 2022/01/17 10:31:08 Phase context status code:  Message:
# [Container] 2022/01/17 10:31:09 Entering phase POST_BUILD
# [Container] 2022/01/17 10:31:09 Running command echo Build completed on `date`
# Build completed on Mon Jan 17 10:31:09 UTC 2022
#
# [Container] 2022/01/17 10:31:09 Running command echo Pushing the Docker image...
# Pushing the Docker image...
#
# [Container] 2022/01/17 10:31:09 Running command docker push $AWS_ACCOUNT_ID.dkr.ecr.$AWS_DEFAULT_REGION.amazonaws.com/$IMAGE_REPO_NAME:$IMAGE_TAG
# The push refers to repository [111122223333.dkr.ecr.ap-southeast-1.amazonaws.com/sm-scikit-ocrtools]
# e6437a1eba77: Preparing
# 7a230815c1a0: Preparing
# 10594c1b6bf0: Preparing
# 7f2cc2962714: Preparing
# 3eb0c6ba5ae4: Preparing
# 43ee5ad7b4a6: Preparing
# 6d17cd513eba: Preparing
# 52cf58251e9e: Preparing
# e54d0f52b878: Preparing
# 24906efbaeb9: Preparing
# 056d28cf3883: Preparing
# 5f08512fd434: Preparing
# c7bb31fc0e08: Preparing
# 50858308da3d: Preparing
# 6d17cd513eba: Waiting
# 52cf58251e9e: Waiting
# e54d0f52b878: Waiting
# 24906efbaeb9: Waiting
# 056d28cf3883: Waiting
# 5f08512fd434: Waiting
# c7bb31fc0e08: Waiting
# 50858308da3d: Waiting
# 43ee5ad7b4a6: Waiting
# 7a230815c1a0: Pushed
# 7f2cc2962714: Pushed
# 3eb0c6ba5ae4: Pushed
# 10594c1b6bf0: Pushed
# 52cf58251e9e: Pushed
# e54d0f52b878: Pushed
# 24906efbaeb9: Pushed
# 5f08512fd434: Pushed
# c7bb31fc0e08: Pushed
# 50858308da3d: Pushed
# e6437a1eba77: Pushed
# 43ee5ad7b4a6: Pushed
# 056d28cf3883: Pushed
#
# 6d17cd513eba: Pushed
# pytorch-1.7-cpu: digest: sha256:41d409579717fc2b7e1765bf045d95661262e431dc23690fc3256d5377920738 size: 3256
#
# [Container] 2022/01/17 10:33:32 Phase complete: POST_BUILD State: SUCCEEDED
# [Container] 2022/01/17 10:33:32 Phase context status code:  Message:
# Image URI: 111122223333.dkr.ecr.ap-southeast-1.amazonaws.com/sm-scikit-ocrtools:pytorch-1.7-cpu

# %%
# Check from notebook whether the image was successfully created:
ecr = boto3.client("ecr")
imgs_desc = ecr.describe_images(
    registryId=account_id,
    repositoryName=ecr_repo_name,
    imageIds=[{"imageTag": ecr_image_tag}],
)
assert len(imgs_desc["imageDetails"]) > 0, f"Couldn't find ECR image {ecr_image_uri} after build"

# %% [markdown]
# Next, we need to **define the inputs** for the processing job.
#
# To process the whole `data/raw` corpus, you could simply pass the whole `data/raw` prefix in S3 as input to the job (As shown in the commented-out *Option 2* below) and scale up the job's compute resources to complete the work quickly.
#
# To process just a sample subset of files for speed in our demo, we'll create a **manifest file** listing just the documents we want.
#
# > ▶️ **Note:** 'Non-augmented' manifest files are still JSON-based, but a different format from the other dataset manifests we'll be using through this sample. You can find guidance on the [S3DataSource API doc](https://docs.aws.amazon.com/sagemaker/latest/APIReference/API_S3DataSource.html) for manifests as used here, and separate information in the [Ground Truth documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-input-data-input-manifest.html) on the "augmented" manifests as used later with SageMaker Ground Truth.

# %%
from sagemaker.processing import ProcessingInput, ProcessingOutput, ScriptProcessor

imgs_s3uri = f"s3://{bucket_name}/{bucket_prefix}data/imgs-clean"

#### OPTION 1: For processing the rel_filepaths_sample subset of raw docs only:
# Prepare a manifest file:
os.makedirs("data/manifests", exist_ok=True)
preproc_input_manifest_path = "data/manifests/raw-dataclean-input.manifest.json"
with open(preproc_input_manifest_path, "w") as f:
    f.write(json.dumps([{"prefix": raw_s3uri + "/"}] + rel_filepaths_sample))

# Upload the manifest to S3:
preproc_input_manifest_s3uri = f"s3://{bucket_name}/{bucket_prefix}{preproc_input_manifest_path}"
# !aws s3 cp {preproc_input_manifest_path} {preproc_input_manifest_s3uri}

# Set the processing job inputs to reference the manifest:
preproc_inputs = [
    ProcessingInput(
        destination="/opt/ml/processing/input/raw",  # Expected input location, per our script
        input_name="raw",
        s3_data_distribution_type="ShardedByS3Key",  # Distribute between instances, if multiple
        s3_data_type="ManifestFile",
        source=preproc_input_manifest_s3uri,  # Manifest of sample raw documents
    ),
]
print("Selected sample subset of documents")
#### END OPTION 1

#### OPTION 2: For processing the whole data/raw folder:
# preproc_inputs = [
#     ProcessingInput(
#         destination="/opt/ml/processing/input/raw",  # Expected input location, per our script
#         input_name="raw",
#         s3_data_distribution_type="ShardedByS3Key",  # Distribute between instances, if multiple
#         source=raw_s3uri,  # S3 prefix for full raw document collection
#     ),
# ]
# print("Selected whole corpus")
#### END OPTION 2
# Out:
# upload: data/manifests/raw-dataclean-input.manifest.json to s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/manifests/raw-dataclean-input.manifest.json
# Selected sample subset of documents

# %%
dir(preproc_inputs[0])
for _ in dir(preproc_inputs[0]):
    if _.startswith('_'):
        continue
    print(_, getattr(preproc_inputs[0], _), sep=' = ')
# Out:
# app_managed = False
# dataset_definition = None
# destination = /opt/ml/processing/input/raw
# input_name = raw
# s3_compression_type = None
# s3_data_distribution_type = ShardedByS3Key
# s3_data_type = ManifestFile
# s3_input = S3Input(s3_uri='s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/manifests/raw-dataclean-input.manifest.json',local_path='/opt/ml/processing/input/raw',s3_data_type='ManifestFile',s3_input_mode='File',s3_data_distribution_type='ShardedByS3Key',s3_compression_type='None')
# s3_input_mode = File
# source = s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/manifests/raw-dataclean-input.manifest.json

# %% [markdown]
# The script we'll be using to process the documents is in the same folder as the Dockerfile used earlier to build the container image: [preproc/imgclean.py](preproc/imgclean.py).
#
# The code parallelizes processing across available CPUs, and the `ShardedByS3Key` setting used on our [ProcessingInput](https://sagemaker.readthedocs.io/en/stable/api/training/processing.html#sagemaker.processing.ProcessingInput) above distributes documents between instances if multiple are provided. This means you should be able to adjust both `instance_type` and `instance_count` below, and still take advantage of the resources configured. The process is typically CPU-bound, so the `ml.c*` families are likely a good fit.
#
# The cell below will **run the processing job** and show logs from the job as it progresses. You can also check up on the status and history of jobs in the [Processing page of the Amazon SageMaker Console](https://console.aws.amazon.com/sagemaker/home?#/processing-jobs).
#
# > ⏰ **Note:** In our tests, it took (including job start-up overheads):
# >
# > - About 9 minutes to process the 120-document sample with 2x `ml.c5.xlarge` instances
# > - About 17 minutes to process the full 2,541-document corpus with 5x `ml.c5.4xlarge` instances.

# %%
# %%time
processor = ScriptProcessor(
    base_job_name="ocr-img-dataclean",
    command=["python3"],
    image_uri=ecr_image_uri,  # As created above
    instance_count=2,
    instance_type="ml.c5.xlarge",
    max_runtime_in_seconds=60 * 60,
    role=sagemaker.get_execution_role(),
    volume_size_in_gb=15,
)

processor.run(
    code="preproc/imgclean.py",  # PDF splitting / image conversion script
    inputs=preproc_inputs,  # Either whole corpus or sample, as above
    outputs=[
        ProcessingOutput(
            destination=imgs_s3uri,
            output_name="imgs-clean",
            s3_upload_mode="Continuous",
            source="/opt/ml/processing/output/imgs-clean",  # Output folder, per our script
        )
    ],
)
# Out:
# Job Name:  ocr-img-dataclean-2022-01-17-10-47-11-923
# Inputs:  [{'InputName': 'raw', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/manifests/raw-dataclean-input.manifest.json', 'LocalPath': '/opt/ml/processing/input/raw', 'S3DataType': 'ManifestFile', 'S3InputMode': 'File', 'S3DataDistributionType': 'ShardedByS3Key', 'S3CompressionType': 'None'}}, {'InputName': 'code', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-southeast-1-111122223333/ocr-img-dataclean-2022-01-17-10-47-11-923/input/code/imgclean.py', 'LocalPath': '/opt/ml/processing/input/code', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'imgs-clean', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/imgs-clean', 'LocalPath': '/opt/ml/processing/output/imgs-clean', 'S3UploadMode': 'Continuous'}}]
# ..........................2022-01-17 10:51:19,034 preproc [INFO] Reading raw files from /opt/ml/processing/input/raw
# 2022-01-17 10:51:19,035 preproc [INFO] Processing 60 files across 4 processes
# 2022-01-17 10:51:19,554 preproc [INFO] Converting /opt/ml/processing/input/raw/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard.pdf to /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-*.png
# 2022-01-17 10:51:19,554 preproc [INFO] Converting /opt/ml/processing/input/raw/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement.pdf to /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-*.png
# 2022-01-17 10:51:19,554 preproc [INFO] Converting /opt/ml/processing/input/raw/American Express National Bank/American Express Gold Card Cardmember Agreement.pdf to /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-*.png
# 2022-01-17 10:51:19,554 preproc [INFO] Converting /opt/ml/processing/input/raw/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement.pdf to /opt/ml/processing/output/imgs-clean/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement-*.png
# 2022-01-17 10:51:18,889 preproc [INFO] Reading raw files from /opt/ml/processing/input/raw
# 2022-01-17 10:51:18,890 preproc [INFO] Processing 60 files across 4 processes
# 2022-01-17 10:51:19,405 preproc [INFO] Converting /opt/ml/processing/input/raw/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure.pdf to /opt/ml/processing/output/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-*.png
# 2022-01-17 10:51:19,405 preproc [INFO] Converting /opt/ml/processing/input/raw/American Express National Bank/American Express Green Card Cardmember Agreement.pdf to /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-*.png
# 2022-01-17 10:51:19,405 preproc [INFO] Converting /opt/ml/processing/input/raw/Associated Credit Union/Visa Credit Card Agreement and Disclosures.pdf to /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-*.png
# 2022-01-17 10:51:19,405 preproc [INFO] Converting /opt/ml/processing/input/raw/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard.pdf to /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-*.png
# 2022-01-17 10:51:29,412 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure.pdf:
#     - /opt/ml/processing/output/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-0001-6.png
# 2022-01-17 10:51:29,413 preproc [INFO] Processed doc 1 of 60
# 2022-01-17 10:51:29,913 preproc [INFO] Converting /opt/ml/processing/input/raw/Berkshire Bank/Credit Card Agreement for Secured Cards.pdf to /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-*.png
# 2022-01-17 10:51:30,440 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement-0001-6.png
#     - /opt/ml/processing/output/imgs-clean/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement-0001-7.png
# 2022-01-17 10:51:30,440 preproc [INFO] Processed doc 1 of 60
# 2022-01-17 10:51:30,605 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-14.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-15.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement-0001-16.png
# 2022-01-17 10:51:30,606 preproc [INFO] Processed doc 2 of 60
# 2022-01-17 10:51:30,941 preproc [INFO] Converting /opt/ml/processing/input/raw/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047.pdf to /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-*.png
# 2022-01-17 10:51:31,107 preproc [INFO] Converting /opt/ml/processing/input/raw/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL.pdf to /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-*.png
# 2022-01-17 10:51:31,599 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Associated Credit Union/Visa Credit Card Agreement and Disclosures.pdf:
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-14.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-15.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-16.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-17.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-18.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-19.png
#     - /opt/ml/processing/output/imgs-clean/Associated Credit Union/Visa Credit Card Agreement and Disclosures-0001-20.png
# 2022-01-17 10:51:31,600 preproc [INFO] Processed doc 2 of 60
# 2022-01-17 10:51:32,101 preproc [INFO] Converting /opt/ml/processing/input/raw/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards.pdf to /opt/ml/processing/output/imgs-clean/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards-*.png
# 2022-01-17 10:51:36,681 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard.pdf:
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-14.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-15.png
#     - /opt/ml/processing/output/imgs-clean/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard-0001-16.png
# 2022-01-17 10:51:36,682 preproc [INFO] Processed doc 3 of 60
# 2022-01-17 10:51:37,183 preproc [INFO] Converting /opt/ml/processing/input/raw/Chase Bank USA/COL00062 Disney Visa Signature Agreement.pdf to /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-*.png
# 2022-01-17 10:51:39,899 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/American Express National Bank/American Express Green Card Cardmember Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Green Card Cardmember Agreement-0001-10.png
# 2022-01-17 10:51:39,900 preproc [INFO] Processed doc 4 of 60
# 2022-01-17 10:51:40,401 preproc [INFO] Converting /opt/ml/processing/input/raw/Citibank/Citi Simplicity Card Pricing Information Table.pdf to /opt/ml/processing/output/imgs-clean/Citibank/Citi Simplicity Card Pricing Information Table-*.png
# 2022-01-17 10:51:39,409 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard.pdf:
#     - /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-0001-6.png
#     - /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-0001-7.png
#     - /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-0001-8.png
#     - /opt/ml/processing/output/imgs-clean/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard-0001-9.png
# 2022-01-17 10:51:39,410 preproc [INFO] Processed doc 3 of 60
# 2022-01-17 10:51:39,911 preproc [INFO] Converting /opt/ml/processing/input/raw/Citibank/Citi Double Cash Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-*.png
# 2022-01-17 10:51:40,427 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/American Express National Bank/American Express Gold Card Cardmember Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/American Express National Bank/American Express Gold Card Cardmember Agreement-0001-10.png
# 2022-01-17 10:51:40,427 preproc [INFO] Processed doc 4 of 60
# 2022-01-17 10:51:40,928 preproc [INFO] Converting /opt/ml/processing/input/raw/Citibank/Drive Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Citibank/Drive Card Agreement-*.png
# 2022-01-17 10:51:42,678 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citibank/Citi Simplicity Card Pricing Information Table.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Simplicity Card Pricing Information Table-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Simplicity Card Pricing Information Table-0001-2.png
# 2022-01-17 10:51:42,679 preproc [INFO] Processed doc 5 of 60
# 2022-01-17 10:51:43,179 preproc [INFO] Converting /opt/ml/processing/input/raw/Citibank/Expedia Rewards Card from Citi Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-*.png
# 2022-01-17 10:51:45,827 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards.pdf:
#     - /opt/ml/processing/output/imgs-clean/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards-0001-6.png
#     - /opt/ml/processing/output/imgs-clean/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards-0001-7.png
#     - /opt/ml/processing/output/imgs-clean/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards-0001-8.png
# 2022-01-17 10:51:45,827 preproc [INFO] Processed doc 6 of 60
# 2022-01-17 10:51:46,328 preproc [INFO] Converting /opt/ml/processing/input/raw/Citibank/Meijer Credit Card Pricing and Information Table.pdf to /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Pricing and Information Table-*.png
# 2022-01-17 10:51:48,073 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citibank/Meijer Credit Card Pricing and Information Table.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Pricing and Information Table-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Pricing and Information Table-0001-2.png
# 2022-01-17 10:51:48,074 preproc [INFO] Processed doc 7 of 60
# 2022-01-17 10:51:48,428 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL.pdf:
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL-0001-12.png
# 2022-01-17 10:51:48,429 preproc [INFO] Processed doc 5 of 60
# 2022-01-17 10:51:48,930 preproc [INFO] Converting /opt/ml/processing/input/raw/Citibank/Meijer Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Agreement-*.png
# 2022-01-17 10:51:48,574 preproc [INFO] Converting /opt/ml/processing/input/raw/Citibank/Sears Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Citibank/Sears Card Agreement-*.png
# 2022-01-17 10:51:52,207 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047.pdf:
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047-0001-14.png
# 2022-01-17 10:51:52,208 preproc [INFO] Processed doc 6 of 60
# 2022-01-17 10:51:52,660 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citibank/Drive Card Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citibank/Drive Card Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Drive Card Agreement-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Drive Card Agreement-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Drive Card Agreement-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Drive Card Agreement-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Drive Card Agreement-0001-6.png
# 2022-01-17 10:51:52,661 preproc [INFO] Processed doc 7 of 60
# 2022-01-17 10:51:52,708 preproc [INFO] Converting /opt/ml/processing/input/raw/Citibank/Office Depot Personal Credit Account Agreement.pdf to /opt/ml/processing/output/imgs-clean/Citibank/Office Depot Personal Credit Account Agreement-*.png
# 2022-01-17 10:51:53,161 preproc [INFO] Converting /opt/ml/processing/input/raw/Citibank/Shop Your Way Mastercard Pricing Information Table.pdf to /opt/ml/processing/output/imgs-clean/Citibank/Shop Your Way Mastercard Pricing Information Table-*.png
# 2022-01-17 10:51:55,128 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citibank/Shop Your Way Mastercard Pricing Information Table.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citibank/Shop Your Way Mastercard Pricing Information Table-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Shop Your Way Mastercard Pricing Information Table-0001-2.png
# 2022-01-17 10:51:55,129 preproc [INFO] Processed doc 8 of 60
# 2022-01-17 10:51:55,629 preproc [INFO] Converting /opt/ml/processing/input/raw/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement.pdf to /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-*.png
# 2022-01-17 10:51:59,448 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Chase Bank USA/COL00062 Disney Visa Signature Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-14.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-15.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-16.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-17.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-18.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-19.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-20.png
#     - /opt/ml/processing/output/imgs-clean/Chase Bank USA/COL00062 Disney Visa Signature Agreement-0001-21.png
# 2022-01-17 10:51:59,450 preproc [INFO] Processed doc 8 of 60
# 2022-01-17 10:51:59,950 preproc [INFO] Converting /opt/ml/processing/input/raw/Citizens Bank/Cash Back Plus Cardholder Agreement.pdf to /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-*.png
# 2022-01-17 10:52:01,033 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citibank/Meijer Credit Card Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Agreement-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Agreement-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Agreement-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Agreement-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Meijer Credit Card Agreement-0001-6.png
# 2022-01-17 10:52:01,034 preproc [INFO] Processed doc 9 of 60
# 2022-01-17 10:52:01,255 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citibank/Sears Card Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citibank/Sears Card Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Sears Card Agreement-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Sears Card Agreement-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Sears Card Agreement-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Sears Card Agreement-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Sears Card Agreement-0001-6.png
# 2022-01-17 10:52:01,256 preproc [INFO] Processed doc 9 of 60
# 2022-01-17 10:52:01,468 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citibank/Citi Double Cash Card Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Citi Double Cash Card Agreement-0001-13.png
# 2022-01-17 10:52:01,469 preproc [INFO] Processed doc 10 of 60
# 2022-01-17 10:52:01,535 preproc [INFO] Converting /opt/ml/processing/input/raw/Comenity Bank/Buckle Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-*.png
# 2022-01-17 10:52:01,970 preproc [INFO] Converting /opt/ml/processing/input/raw/Comenity Bank/DSW Visa and Visa Signature Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Comenity Bank/DSW Visa and Visa Signature Credit Card Agreement-*.png
# 2022-01-17 10:52:01,661 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Berkshire Bank/Credit Card Agreement for Secured Cards.pdf:
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-14.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-15.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-16.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-17.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-18.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-19.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-20.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-21.png
#     - /opt/ml/processing/output/imgs-clean/Berkshire Bank/Credit Card Agreement for Secured Cards-0001-22.png
# 2022-01-17 10:52:01,664 preproc [INFO] Processed doc 10 of 60
# 2022-01-17 10:52:01,757 preproc [INFO] Converting /opt/ml/processing/input/raw/Comenity Bank/Adorama Credit Card - Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Comenity Bank/Adorama Credit Card - Credit Card Agreement-*.png
# 2022-01-17 10:52:02,165 preproc [INFO] Converting /opt/ml/processing/input/raw/Comenity Bank/Caesars Rewards Visa and Rewards Visa Signature Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Comenity Bank/Caesars Rewards Visa and Rewards Visa Signature Credit Card Agreement-*.png
# 2022-01-17 10:52:04,771 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citibank/Office Depot Personal Credit Account Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citibank/Office Depot Personal Credit Account Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Office Depot Personal Credit Account Agreement-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Office Depot Personal Credit Account Agreement-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Office Depot Personal Credit Account Agreement-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Office Depot Personal Credit Account Agreement-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Office Depot Personal Credit Account Agreement-0001-6.png
# 2022-01-17 10:52:04,772 preproc [INFO] Processed doc 11 of 60
# 2022-01-17 10:52:04,442 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citibank/Expedia Rewards Card from Citi Card Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/Citibank/Expedia Rewards Card from Citi Card Agreement-0001-13.png
# 2022-01-17 10:52:04,443 preproc [INFO] Processed doc 11 of 60
# 2022-01-17 10:52:04,944 preproc [INFO] Converting /opt/ml/processing/input/raw/Comenity Bank/Jared The Galleria Of Jewelry Gold Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Comenity Bank/Jared The Galleria Of Jewelry Gold Credit Card Agreement-*.png
# 2022-01-17 10:52:05,272 preproc [INFO] Converting /opt/ml/processing/input/raw/Comenity Bank/fullbeauty Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Comenity Bank/fullbeauty Credit Card Agreement-*.png
# 2022-01-17 10:52:13,242 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement-0001-11.png
# 2022-01-17 10:52:13,243 preproc [INFO] Processed doc 12 of 60
# 2022-01-17 10:52:13,744 preproc [INFO] Converting /opt/ml/processing/input/raw/Comenity Capital Bank/Alphaeon Vision Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Comenity Capital Bank/Alphaeon Vision Credit Card Agreement-*.png
# 2022-01-17 10:52:14,836 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Citizens Bank/Cash Back Plus Cardholder Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-14.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-15.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-16.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-17.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-18.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-19.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-20.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-21.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-22.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-23.png
#     - /opt/ml/processing/output/imgs-clean/Citizens Bank/Cash Back Plus Cardholder Agreement-0001-24.png
# 2022-01-17 10:52:14,837 preproc [INFO] Processed doc 12 of 60
# 2022-01-17 10:52:15,338 preproc [INFO] Converting /opt/ml/processing/input/raw/Comenity Bank/west elm Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Comenity Bank/west elm Credit Card Agreement-*.png
# 2022-01-17 10:52:30,099 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Comenity Bank/Buckle Credit Card Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-14.png
#     - /opt/ml/processing/output/imgs-clean/Comenity Bank/Buckle Credit Card Agreement-0001-15.png
# ...
#     - /opt/ml/processing/output/imgs-clean/OMNI Community Credit Union/MasterCard Agreements and Disclosures-0001-31.png
# 2022-01-17 10:54:57,783 preproc [INFO] Processed doc 55 of 60
# 2022-01-17 10:54:58,284 preproc [INFO] Converting /opt/ml/processing/input/raw/US Eagle Federal Credit Union/Eagle Classic Credit Card Disclosure and Agreement.pdf to /opt/ml/processing/output/imgs-clean/US Eagle Federal Credit Union/Eagle Classic Credit Card Disclosure and Agreement-*.png
# 2022-01-17 10:54:58,454 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/TD Bank USA NA/Nordstrom Visa Signature and Nordstrom Credit Card Account Opening Disclosure.pdf:
#     - /opt/ml/processing/output/imgs-clean/TD Bank USA NA/Nordstrom Visa Signature and Nordstrom Credit Card Account Opening Disclosure-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/TD Bank USA NA/Nordstrom Visa Signature and Nordstrom Credit Card Account Opening Disclosure-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/TD Bank USA NA/Nordstrom Visa Signature and Nordstrom Credit Card Account Opening Disclosure-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/TD Bank USA NA/Nordstrom Visa Signature and Nordstrom Credit Card Account Opening Disclosure-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/TD Bank USA NA/Nordstrom Visa Signature and Nordstrom Credit Card Account Opening Disclosure-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/TD Bank USA NA/Nordstrom Visa Signature and Nordstrom Credit Card Account Opening Disclosure-0001-6.png
#     - /opt/ml/processing/output/imgs-clean/TD Bank USA NA/Nordstrom Visa Signature and Nordstrom Credit Card Account Opening Disclosure-0001-7.png
# 2022-01-17 10:54:58,455 preproc [INFO] Processed doc 54 of 60
# 2022-01-17 10:54:58,956 preproc [INFO] Converting /opt/ml/processing/input/raw/Truwest Credit Union/Visa Account Agreement.pdf to /opt/ml/processing/output/imgs-clean/Truwest Credit Union/Visa Account Agreement-*.png
# 2022-01-17 10:55:01,517 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/The Bank of Missouri/Milestone Gold_AJ Cardholder Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AJ Cardholder Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AJ Cardholder Agreement-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AJ Cardholder Agreement-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AJ Cardholder Agreement-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AJ Cardholder Agreement-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AJ Cardholder Agreement-0001-6.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AJ Cardholder Agreement-0001-7.png
# 2022-01-17 10:55:01,517 preproc [INFO] Processed doc 56 of 60
# 2022-01-17 10:55:01,547 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/US Eagle Federal Credit Union/Eagle Classic Credit Card Disclosure and Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/US Eagle Federal Credit Union/Eagle Classic Credit Card Disclosure and Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/US Eagle Federal Credit Union/Eagle Classic Credit Card Disclosure and Agreement-0001-2.png
# 2022-01-17 10:55:01,547 preproc [INFO] Processed doc 57 of 60
# 2022-01-17 10:55:02,018 preproc [INFO] Converting /opt/ml/processing/input/raw/Washington Trust Bank/Personal Credit Card Disclosures.pdf to /opt/ml/processing/output/imgs-clean/Washington Trust Bank/Personal Credit Card Disclosures-*.png
# 2022-01-17 10:55:02,549 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Synovus Bank/Secured Visa Credit Cardholder Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Synovus Bank/Secured Visa Credit Cardholder Agreement-0001-12.png
# 2022-01-17 10:55:02,550 preproc [INFO] Processed doc 55 of 60
# 2022-01-17 10:55:03,050 preproc [INFO] Converting /opt/ml/processing/input/raw/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement-*.png
# 2022-01-17 10:55:03,494 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Washington Trust Bank/Personal Credit Card Disclosures.pdf:
#     - /opt/ml/processing/output/imgs-clean/Washington Trust Bank/Personal Credit Card Disclosures-0001-1.png
# 2022-01-17 10:55:03,495 preproc [INFO] Processed doc 58 of 60
# 2022-01-17 10:55:05,926 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/TD Bank NA/Rooms to Go Account Summary Table and Cardholder Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/TD Bank NA/Rooms to Go Account Summary Table and Cardholder Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/TD Bank NA/Rooms to Go Account Summary Table and Cardholder Agreement-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/TD Bank NA/Rooms to Go Account Summary Table and Cardholder Agreement-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/TD Bank NA/Rooms to Go Account Summary Table and Cardholder Agreement-0001-4.png
# 2022-01-17 10:55:05,926 preproc [INFO] Processed doc 59 of 60
# 2022-01-17 10:55:03,577 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Truwest Credit Union/Visa Account Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Truwest Credit Union/Visa Account Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Truwest Credit Union/Visa Account Agreement-0001-2.png
# 2022-01-17 10:55:03,578 preproc [INFO] Processed doc 56 of 60
# 2022-01-17 10:55:04,079 preproc [INFO] Converting /opt/ml/processing/input/raw/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement.pdf to /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-*.png
# 2022-01-17 10:55:06,468 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/The Bank of Missouri/Milestone Gold_AI Cardholder Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AI Cardholder Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AI Cardholder Agreement-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AI Cardholder Agreement-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AI Cardholder Agreement-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AI Cardholder Agreement-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AI Cardholder Agreement-0001-6.png
#     - /opt/ml/processing/output/imgs-clean/The Bank of Missouri/Milestone Gold_AI Cardholder Agreement-0001-7.png
# 2022-01-17 10:55:06,468 preproc [INFO] Processed doc 57 of 60
# 2022-01-17 10:55:11,798 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure.pdf:
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure-0001-14.png
# 2022-01-17 10:55:11,799 preproc [INFO] Processed doc 58 of 60
# 2022-01-17 10:55:17,778 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement-0001-11.png
# 2022-01-17 10:55:17,778 preproc [INFO] Processed doc 59 of 60
# 2022-01-17 10:55:17,791 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement.pdf:
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-01.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-02.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-03.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-04.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-05.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-06.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-07.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-08.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-09.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-10.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-11.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-12.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-13.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-14.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-15.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-16.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-17.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-18.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-19.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-20.png
#     - /opt/ml/processing/output/imgs-clean/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement-0001-21.png
# 2022-01-17 10:55:17,792 preproc [INFO] Processed doc 60 of 60
# 2022-01-17 10:55:17,860 preproc [INFO] All done!
# 2022-01-17 10:55:24,831 preproc [INFO] * PDF converted /opt/ml/processing/input/raw/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement.pdf:
#     - /opt/ml/processing/output/imgs-clean/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement-0001-1.png
#     - /opt/ml/processing/output/imgs-clean/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement-0001-2.png
#     - /opt/ml/processing/output/imgs-clean/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement-0001-3.png
#     - /opt/ml/processing/output/imgs-clean/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement-0001-4.png
#     - /opt/ml/processing/output/imgs-clean/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement-0001-5.png
#     - /opt/ml/processing/output/imgs-clean/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement-0001-6.png
# 2022-01-17 10:55:24,832 preproc [INFO] Processed doc 60 of 60
# 2022-01-17 10:55:24,836 preproc [INFO] All done!
#
# CPU times: user 1.5 s, sys: 114 ms, total: 1.61 s
# Wall time: 8min 49s

# %% [markdown]
# Once the images have been extracted, we'll also download them locally to the notebook for use in visualizations later:

# %%
print(f"Downloading cleaned images from {imgs_s3uri}...")
# !aws s3 sync --quiet {imgs_s3uri} data/imgs-clean
print("Done")
# Out:
# Downloading cleaned images from s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/imgs-clean...
# Done

# %% [markdown]
# ### Textract the input documents
#
# Since we need to be mindful of the Amazon Textract service [quotas](https://docs.aws.amazon.com/general/latest/gr/textract.html#limits_textract) when processing large batches of documents, and the OCR pipeline solution stack is already set up - we'll use just the **OCR/Textract portion of the pipeline** to run our documents through Textract in bulk.
#
# > ⏰ **Note:** The code below may take ~6 minutes to run against a 120-document sample set and may encounter occasional rate-limiting errors. **If you see errors in the output, try re-running the cell**: Successfully processed files will be skipped in repeat runs.
#
# > ⚠️ **Note:** Refer to the [Amazon Textract Pricing Page](https://aws.amazon.com/textract/pricing/) for up-to-date guidance before running large extraction jobs.
# >
# > At the time of writing, the projected cost (in `us-east-1`, ignoring free tier allowances) of analyzing 100 documents with 10 pages on average was approximately \\$67 with `TABLES` and `FORMS` enabled, or \\$2 without. Across the full corpus, we measured the average number of pages per document at approximately 6.7.

# %%
textract_s3uri = f"s3://{bucket_name}/{bucket_prefix}data/textracted"

# %%
textract_results = util.preproc.call_textract(
    textract_sfn_arn=config.plain_textract_sfn_arn,
    input_base_s3uri=raw_s3uri,
    # Can instead set rel_filepaths, to process the whole dataset (see cost note above):
    input_relpaths=rel_filepaths_sample,
    # You can un-comment the below `features` line to turn on both TABLES and FORMS extraction, but
    # note that this could have a significant impact on API costs:
    features=[],
    output_base_s3uri=textract_s3uri,
    skip_existing=True,
)
# Out:
# Textracting PDFs...:   0%|          | 0/120 [00:00<?, ?it/s]
# Starting jobs...:   0%|          | 0/120 [00:00<?, ?it/s]

# %%
textract_s3uris
# Out:
# [
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/American Express National Bank/American Express Gold Card Cardmember Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/American Express National Bank/American Express Green Card Cardmember Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Arkansas Federal Credit Union/Visa Credit Line Account Agreement and Federal Disclosure Statement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Associated Credit Union/Visa Credit Card Agreement and Disclosures.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/BMO Harris Bank/Diners Club Credit Card Cardmember Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/BMO Harris Bank/Mastercard Guide to Benefits ΓÇô Platinum Mastercard, Platinum Rewards Mastercard and Cash Back Mastercard.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Banco Popular de Puerto Rico/Credit Card Agreement for JetBlue Mastercard.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Berkshire Bank/Credit Card Agreement for Secured Cards.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Capital Bank/OpenSky Secured Visa Credit Cardholder Agreement SKY1-047.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Capital One Bank/Credit Card Agreement for Visa Signature and World MasterCard Cards.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Celtic Bank/CFC - Celtic Bank Cardholder Agreement 25.9% APR, $99 AF, $750 CL.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Chase Bank USA/COL00062 Disney Visa Signature Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citibank/Citi Double Cash Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citibank/Citi Simplicity Card Pricing Information Table.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citibank/Drive Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citibank/Expedia Rewards Card from Citi Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citibank/Meijer Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citibank/Meijer Credit Card Pricing and Information Table.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citibank/Office Depot Personal Credit Account Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citibank/Sears Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citibank/Shop Your Way Mastercard Pricing Information Table.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Citizens Bank/Cash Back Plus Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/City National Bank/Visa Platinum Credit Card Pricing Information and Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Bank/Adorama Credit Card - Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Bank/Buckle Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Bank/Caesars Rewards Visa and Rewards Visa Signature Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Bank/DSW Visa and Visa Signature Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Bank/Jared The Galleria Of Jewelry Gold Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Bank/fullbeauty Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Bank/west elm Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Alphaeon Vision Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Big Lots Credit Card.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Gardner-White Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/IKEA Projekt Credit Card Agreement.pdf/consolidated.json',
#     "s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Lands' End Visa and Visa Signature Credit Card Agreement.pdf/consolidated.json",
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Lending Club Patient Solutions Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Modells MVP.pdf/consolidated.json',
#     "s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/My Place Rewards (The Children's Place) Credit Card Agreement.pdf/consolidated.json",
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Overstock Store Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Petland Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/The Tile Shop.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/The Tog Shop.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Toyota Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Zales Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Comenity Capital Bank/Zales Outlet Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Commerce Bank/Bryant University Alumni Rewards Visa Credit Card Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Commerce Bank/Employee Special Connections Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Commerce Bank/Georgia Tech Rewards Mastercard Pricing Information.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Commerce Bank/Lindenwood Rewards Visa Card Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Commerce Bank/Private Banking Visa Signature Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Credit Human Federal Credit Union/Rate Preferred Visa Application and Solicitation Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Credit Union of America/Visa Signature Credit Card Agreement and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/DATCU Credit Union/Mastercard Agreement and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Denali Federal Credit Union/Visa Credit Card Account Agreement and Disclosures.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Department Stores National Bank/Department Stores National Bank Privacy Notice - Bloomingdales.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/DuPage Credit Union/Visa Inspire Cash Back Signature Truth in Lending Terms and Conditions.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/ESL Federal Credit Union/Rewards Visa Signature Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Energy Capital Credit Union/Visa Platinum Credit Card Application and Solicitation Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Fairwinds Credit Union/Secured Visa Agreement and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Farm Bureau Bank/World Platinum Terms and Conditions.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/First Arkansas Bank and Trust/World Elite Consumer Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/First Community Credit Union (MO)/Visa Classic Secured Credit Card Disclosures and Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/First Electronic Bank/Genesis Credit Account Agreement - Wayfair - 29.9.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/First Financial Bank/Visa Credit Card Terms and Conditions.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/First International Bank and Trust/4234772 Badlands Visa & MasterCard 2020 Account Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/First PREMIER Bank/Credit Card Agreement and Disclosure 4.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/First PREMIER Bank/Credit Card Agreement and Disclosure 8.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/FivePoint Credit Union/MasterCard (A) Rates Account Opening Disclosure and Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/FivePoint Credit Union/MasterCard (B) Rates Account Opening Disclosure and Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Gesa Credit Union/Visa Credit Line Account Agreement and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/HSBC Bank USA/Premier World Elite Mastercard Cardmember Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Heritage Credit Union/Visa Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/IBERIABANK/Visa Classic Secured Cardholder Agreement and Additional Disclosures.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Investar Bank/Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/JSC Federal Credit Union/Visa Application and Solicitation Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Justice Federal Credit Union/Visa Credit Card Agreement Federal Disclosure Statement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/KeyBank/Key Private Bank MasterCard Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Lake Trust Credit Union/Platinum Elite Rewards Visa Credit Card Account Opening Disclosure (Tier 5).pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Landmark Credit Union/Student Visa Credit Card Agreement and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Los Angeles Police FCU/Classic Visa Agreement and Federal Truth In Lending Disclosure Tier 15.99.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Members 1st Federal Credit Union/Visa Platinum Rewards Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Members 1st Federal Credit Union/Visa Platinum Secured Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Mission Lane LLC/Mission Lane Visa (Formerly Arrow Card) Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Nevada State Bank/Threshold Visa Signature Credit Card Agreement and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Nutmeg State Financial Credit Union/Visa Platinum Online Application and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/OMNI Community Credit Union/MasterCard Agreements and Disclosures.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/OnPoint Community Credit Union/Visa Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Oriental Bank/Oriental MasterCard Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Preferred Credit Inc/Retail Charge Agreement - CT20-W.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Preferred Credit Inc/Retail Charge Agreement - E-UA03-R.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Preferred Credit Inc/Retail Charge Agreement - RI04-R.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Quorum Federal Credit Union/Ratewise MasterCard Credit Card Application and Solicitation Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Randolph Brooks FCU/Platinum Premier Rate MasterCard Agreement and Disclosures.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/SELCO Community Credit Union/Visa Credit Card Account Agreement and Disclosures.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/San Diego County Credit Union/Visa Credit Card Agreement and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Scott Credit Union/Extreme Visa or Visa Secured Agreement and Disclosures.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/State Department Federal Credit Union/Credit Card Disclosures.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Synchrony Bank/Cathay Pacific Visa Card Account Agreement and Pricing Information.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Synchrony Bank/Nissan Visa Card Account Agreement and Pricing Information.pdf/consolidated.json',
#     "s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Synchrony Bank/Sam's Club Credit Card Account Agreement and Pricing Information.pdf/consolidated.json",
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Synchrony Bank/Stein Mart Platinum MasterCard Account Agreement and Pricing Information.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Synchrony Bank/Synchrony MasterCard Account Agreement and Pricing Information.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Synovus Bank/Secured Visa Credit Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/TD Bank NA/Ashley Furniture (Broad River) Account Summary Table and Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/TD Bank NA/Ashley Furniture (City Furniture) Account Summary Table and Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/TD Bank NA/Ashley Furniture (Dufresne Spencer) Account Summary Table and Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/TD Bank NA/Robbins Bros Account Summary Table and Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/TD Bank NA/Rooms to Go Account Summary Table and Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/TD Bank USA NA/Nordstrom Visa Signature and Nordstrom Credit Card Account Opening Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/TIB The Independent BankersBank/Card Disclosure 134.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/The Bank of Missouri/Milestone Gold_AI Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/The Bank of Missouri/Milestone Gold_AJ Cardholder Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Travis Credit Union/Visa Credit Card Cardholder Agreement and Disclosure.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/TruMark Financial Credit Union/Credit Card Agreement and Disclosure Statement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Truwest Credit Union/Visa Account Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/US Eagle Federal Credit Union/Eagle Classic Credit Card Disclosure and Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Utilities Employees Credit Union/Visa Consumer Credit Card Agreement.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Washington Trust Bank/Personal Credit Card Disclosures.pdf/consolidated.json',
#     's3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/Wells Fargo Bank/Hotels.com Rewards Visa Signature Credit Card Agreement.pdf/consolidated.json'
# ]

# %%
textract_s3uris = list(filter(lambda s: isinstance(s, str), textract_results))
with open("data/textracted-all.manifest.jsonl", "w") as f:
    for uri in textract_s3uris:
        f.write(json.dumps({"textract-ref": uri}) + "\n")

print(f"{len(textract_s3uris)} of {len(textract_results)} docs textracted successfully")
if len(textract_s3uris) < len(textract_results):
    raise ValueError(
        "Are you sure you want to continue? Consider re-trying to process the failed docs"
    )
# Out:
# 120 of 120 docs textracted successfully

# %% [markdown]
# ### Collate OCR and image data for annotation
#
# Now we have a filtered corpus of documents with Amazon Textract results, plus cleaned and standardized images for each page - all available on Amazon S3.
#
# To prepare for data annotation and later model training, we'll need to collate these together with a [manifest file](https://docs.aws.amazon.com/sagemaker/latest/dg/augmented-manifest.html#augmented-manifest-format) in JSON-lines format.
#
# Later in the data preparation process we'll have many reasons to slice, dice, and manipulate these manifests via the JSON alone (for example to extract shuffled random subsets for annotation jobs, combine the results of annotation jobs together, etc).
#
# For this **initial cataloguing** linking Textract results to page images though, we'll actually **validate that the artifacts are present on S3** in the expected locations.
#
# > ⏰ Because of these validation checks, the cell below may a minute or two to run against our 120-document sample set.

# %%
warnings = util.preproc.build_data_manifest(
    "data/pages-all-sample.manifest.jsonl",
    rel_doc_paths=rel_filepaths_sample,
    textract_s3uri=textract_s3uri,
    imgs_s3uri=imgs_s3uri,
    by="page",
    no_content="omit",
)

if len(warnings):
    raise ValueError(
        f"Manifest incomplete - {len(warnings)} docs failed. Please see `warnings` for details"
    )
# Out:
# Building data manifest...:   0%|          | 0/120 [00:00<?, ?it/s]

# %% [markdown]
# Let's briefly explore the catalogue we've created.
#
# Each line of the file is a JSON record identifying a particular page:

# %%
with open("data/pages-all-sample.manifest.jsonl", "r") as f:
    for ix, line in enumerate(f):
        print(line, end="")
        if ix >= 2:
            print("...")
            break
# Out:
# {"source-ref": "s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-0001-1.png", "textract-ref": "s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure.pdf/consolidated.json", "page-num": 1}
# {"source-ref": "s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-0001-2.png", "textract-ref": "s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure.pdf/consolidated.json", "page-num": 2}
# {"source-ref": "s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/imgs-clean/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure-0001-3.png", "textract-ref": "s3://sagemaker-ap-southeast-1-111122223333/textract-transformers/data/textracted/American Airlines Federal Credit Union/Visa Credit Card Agreement and Disclosure.pdf/consolidated.json", "page-num": 3}
# ...

# %% [markdown]
# The corpus has a very skewed distribution of number of pages per document, with a few outliers dragging up the average significantly.
#
# In our tests on corpus-wide statistics:
#
# - The overall average was **~6.7 pages per document**
# - The 25th percentile was 3 pages; the 50th percentile was 6 pages; and the 75th percentile was 11 pages
# - The longest document was 402 pages
#
# Your results for sub-sampled sets will likely vary a little - but can be analyzed as below:

# %%
with open("data/pages-all-sample.manifest.jsonl", "r") as f:
    manifest_df = pd.DataFrame([json.loads(l) for l in f])
page_counts_by_doc = manifest_df.groupby("textract-ref")["textract-ref"].count()

print("Document page count statistics")
page_counts_by_doc.describe()
# Out:
# Document page count statistics
#
# count    120.000000
# mean       9.733333
# std        7.383531
# min        1.000000
# 25%        4.000000
# 50%        7.000000
# 75%       16.500000
# max       31.000000
# Name: textract-ref, dtype: float64

# %% [markdown]
# From visually inspecting some sample documents, we found that the first page was often most useful for the kinds of fields defined for extraction:
#
# Many documents used the first page for a fact-sheet/summary, followed by subsequent pages of dense legal terms.
#
# Therefore (since our annotation will be image/page-based rather than document-based) we'll aim to include proportionally more first pages when choosing datasets to annotate.

# %% [markdown]
# ## Annotation infrastructure
#
# To create a labelling job in Amazon SageMaker Ground Truth, we'll need to specify
#
# - **Who's** doing the labelling - which could be your own internal teams, the public crowd via Amazon Mechanical Turk, or skilled workers supplied by vendors through the AWS Marketplace
# - **What** the task will look like - which could be using the [built-in task UIs](https://docs.aws.amazon.com/sagemaker/latest/dg/sms.html) or [custom workflows](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-custom-templates.html).
# - **Where** the input data sourced from and the results will be saved to (locations on Amazon S3)

# %% [markdown]
# ### Create a private workteam
#
# For this demo, you'll set up a private work "team" for just yourself to test out the annotation process.
#
# ▶️ **Open** the [Amazon SageMaker Ground Truth console, *Labeling Workforces* page](https://console.aws.amazon.com/sagemaker/groundtruth?#/labeling-workforces)
#
# > ⚠️ **Check** SM Ground Truth opens in the same **AWS Region** where this notebook and your CloudFormation stack are deployed: You may find it defaults to `N. Virginia`. Use the drop-down in the top right of the screen to switch regions.
#
# ▶️ **Select** the *Private* tab and click **Create private team**
#
# - Choose an appropriate **name** for your team e.g. `just-me`
# - (If you get the option) select to **Invite new workers via email** and enter your email address (you'll need access to this address to log in and annotate the data)
# - And leave the other (Cognito, SNS, etc) parameters as default.
#
# ▶️ **If you didn't get the option** to add workers during team creation (typically because your account is already set up for SageMaker Ground Truth), then after the team is created you can:
#
# - Click **Invite new workers** to add your email address to the workforce, and then
# - Click on your **team name** to open the team details, then navigate to the *Workers tab* to add yourself to the team
#
# ▶️ **Copy** the *name* of your workteam and paste it into the cell below, to store it:

# %%
workteam_name = "just-me"  # TODO: Update this to match yours, if different

workteam_arn = util.smgt.workteam_arn_from_name(workteam_name)

# %% [markdown]
# Finally:
#
# ▶️ **Check your email** for an invitation and log in to the labelling portal. You'll be asked to configure a password on first login.
#
#
# Your completed setup should look something like this in the AWS Console:
#
# ![](img/smgt-private-workforce.png "Screenshot of SageMaker Ground Truth private workforces configuration")

# %% [markdown]
# ### Set up the custom task template
#
# This sample provides 2 options for data annotation:
#
# 1. Use the **built-in [Bounding Box tool](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-bounding-box.html)**
# 2. Use the provided **custom task template** which collects transcription reviews as well as bounding boxes
#
# We recommend **at least experimenting with the custom template** here in the notebook, to get a better understanding of how the model will "see" and use your annotations (and how you might extend this sample for your own use cases).
#
# However, you'll probably want to use the built-in boxes tool for the bulk of your annotating work because:
#
# - The ML model we present (in the next notebook) only supports tagging and cannot be directly trained on the text corrections you collect in the custom template
# - ...And reviewing the text transcription takes extra time & effort
#
# As detailed [in the developer guide](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-custom-templates.html), custom Ground Truth UIs are HTML [Liquid templates](https://shopify.github.io/liquid/basics/introduction/). You can use the [Crowd HTML Elements](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-ui-template-reference.html) to embed standard components, but also include custom HTML/CSS/JS as needed. A set of examples is provided in the [amazon-sagemaker-ground-truth-task-uis repository on GitHub](https://github.com/aws-samples/amazon-sagemaker-ground-truth-task-uis).
#
# Since spinning up a labelling job each time to test and debug a custom template would slow down development, SageMaker provides a [RenderUiTemplate API](https://docs.aws.amazon.com/sagemaker/latest/APIReference/API_RenderUiTemplate.html) for previewing the worker experience.
#
# First, we'll populate the master template `*.liquid.tpl.html` with the entity/field types we configured earlier (and some other automated content) to produce the final SageMaker Ground Truth template `*.liquid.html`:

# %%
from bs4 import BeautifulSoup

with open("annotation/ocr-bbox-and-validation.liquid.tpl.html", "r") as ftpl:
    with open("annotation/ocr-bbox-and-validation.liquid.html", "w") as fout:
        template = BeautifulSoup(ftpl.read())

        annotator_el = template.find(id="annotator")
        annotator_el["header"] = "Highlight entities and review their OCR results."
        annotator_el["labels"] = json.dumps(entity_classes)

        if any(f.annotation_guidance for f in fields):
            full_instructions_el = template.find("full-instructions")
            full_instructions_el.append(
                BeautifulSoup(
                    "\n".join(
                        ["<h3>Per-Field Guidance</h3>"]
                        + [
                            f"<h4>{f.name}</h4>\n{f.annotation_guidance}"
                            for f in fields
                            if f.annotation_guidance
                        ]
                    )
                )
            )

        fout.write(template.prettify())

# %% [markdown]
# To be able to serve our example images through the UI, SageMaker Ground Truth requires the target S3 bucket to be set up [with CORS permissions](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-cors-update.html) (which is not the same as making the bucket or its contents public).
#
# The cell below will ensure these permissions are set on the bucket configured earlier by `bucket_name`:

# %%
s3 = boto3.resource("s3")
bucket_cors = s3.BucketCors(bucket_name)

try:
    existing_rules = bucket_cors.cors_rules
except:
    existing_rules = []

if any(r for r in existing_rules if "*" in r["AllowedOrigins"] and "GET" in r["AllowedMethods"]):
    logger.info(f"Bucket already set up with CORS permissions")
else:
    new_rules = existing_rules + [
        {
            "ID": "SageMakerGroundTruth",
            "AllowedHeaders": [],
            "AllowedMethods": ["GET"],
            "AllowedOrigins": ["*"],
            "ExposeHeaders": [],
            "MaxAgeSeconds": 60,
        },
    ]
    cors_resp = bucket_cors.put(
        CORSConfiguration={"CORSRules": new_rules},
        ExpectedBucketOwner=os.environ["AWS_ACCOUNT_ID"],
    )
    logger.info(f"Added CORS permissions to bucket")

# %% [markdown]
# Now, we're ready to render the preview of what this task would look like with an actual record from the data manifest:

# %%
role = sagemaker.get_execution_role()
smclient = boto3.client("sagemaker")

# Fetch an example record from the manifest:
ix_example = 0
with open("data/pages-all-sample.manifest.jsonl", "r") as fmanifest:
    sample_task_str = None
    for ix, line in enumerate(fmanifest):
        if ix == ix_example:
            sample_task_str = line
            break

# Render the template with the example record:
ui_render_file = "annotation/render.tmp.html"
with open("annotation/ocr-bbox-and-validation.liquid.html", "r") as fui:
    with open(ui_render_file, "w") as frender:
        ui_render_resp = smclient.render_ui_template(
            UiTemplate={"Content": fui.read()},
            Task={"Input": sample_task_str},
            RoleArn=role,
        )
        frender.write(ui_render_resp["RenderedContent"])

print(f"▶️ Open {ui_render_file} and click 'Trust HTML' to see the UI in action!")

# %% [markdown]
# Opening [annotation/render.tmp.html](annotation/render.tmp.html) and clicking **Trust HTML** in the toolbar, you should see a view something similar to the below:
#
# > ℹ️ **Note:** In this task template, you need to click the "Instructions" button to expand the transcription review pane on the left!
#
# ![](img/smgt-custom-template-demo.png "Screenshot of custom annotation UI")

# %% [markdown]
# Note that:
#
# - When you draw a bounding box on the page image, a new OCR result is populated in the left sidebar prompting you to review (and if necessary correct) Textract's transcription of the text in that region.
# - Overlapping bounding boxes of the same type are consolidated, allowing us to highlight non-square regions of text (for example a particular sentence over multiple lines within a paragraph).
# - Transcription review fields are mandatory: The template should not let you submit the result until all transcriptions have been reviewed.
#
# You should aim to follow these same conventions when annotating the sample data, even with the built-in task type. Under the hood, the ML model code applies similar logic to map your bounding box annotations to the Textract detected `WORD`s and `LINE`s.
#
# To use this custom template in a data labeling job, you can adjust the instructions below (which assume you'll use the faster built-in template) as follows:
#
# - Select task category 'Custom' > task type 'Custom', instead of 'Image > Bounding Box'
# - For template body, copy the contents of the `*.liquid.html` file above (**NOT** the `*.tpl.liquid.html`, which has placeholders e.g. for the list of classes)
# - In the tool configuration step, select the `SMGT-Pre` and `SMGT-Post` Lambda functions that have been created for you by the solution stack: These should appear in the drop-down options.
#
# In practice, while it's important to explore how the bounding boxes are being interpreted, we'd recommend to use the simpler built-in template for this walkthrough: To help you complete your data annotation faster.

# %% [markdown]
# ## Annotate data
#
# > ⏰ **If you're short on time**: You can skip the remaining steps in this notebook altogether.
# >
# > We've provided pre-prepared annotations for 100 pages in the `data/annotations` folder, to augment your work and help train an effective model faster. If you need, you can skip along to the next notebook and select **only** the `augmentation-*` datasets instead of labeling your own too. If you choose to do this, your model will likely be less accurate.
#
# We're now ready to start annotating data, and will typically **iterate over multiple jobs** in this step to start small and then boost model accuracy.
#
# To make incrementally adding to the dataset easy, we'll need to pay particular attention to:
#
# - How we sample data for jobs, with good randomness but no repetition of previously-annotated pages
# - How we collect our results to a single consolidated dataset
#
# So let's follow through the steps:

# %% [markdown]
# ### Collect a dataset
#
# Here we will:
#
# - **Shuffle** our data (in a *reproducible*/deterministic way), to ensure we annotate documents/pages from a range of providers - not just concentrating on the first provider/doc(s)
# - **Exclude** any examples for which the page image has **already been labeled** in the `data/annotations` output folder
# - **Stratify** the sample, to obtain a specific (boosted) proportion of first-page samples, since we observed the first pages of documents to often be most useful for the fields of interest.
#
# > ⚠️ If you're using a custom dataset:
# >
# > `select_examples()` below implements a strategy of randomly selecting pages with a fixed, boosted proportion of "page 1s". This might not be appropriate for your use case: For example if you already have a specific planned set of target pages for an extremely small-scale PoC, or if first-page samples are no more relevant than other pages for your documents. Consider revising `select_examples()` to adjust how you select pages for annotation.

# %%
# This cell just defines the necessary functions & constants:

# Keep this the same across the jobs:
annotations_base_s3uri = f"s3://{bucket_name}/{bucket_prefix}data/annotations"


def rel_path_from_s3uri(uri, key_base="data/imgs-clean/") -> str:
    """Extract e.g. 'subfolders/file' from 's3://bucket/.../{key_base}subfolders/file'"""
    return uri[len("s3://") :].partition("/")[2].partition(key_base)[2]


def get_preannotated_imgs(exclude_job_names=[]) -> set:
    """Find the set of relative image paths that have already been annotated"""
    filepaths = set()  # Protect against introducing duplicates
    for job_folder in os.listdir("data/annotations"):
        if job_folder in exclude_job_names:
            logger.info(f"Skipping excluded job {job_folder}")
            continue
        manifest_file = os.path.join(
            "data",
            "annotations",
            job_folder,
            "manifests",
            "output",
            "output.manifest",
        )
        if not os.path.isfile(manifest_file):
            if os.path.isdir(os.path.join("data", "annotations", job_folder)):
                logger.warning(f"Skipping job {job_folder}: No output manifest at {manifest_file}")
            continue
        with open(manifest_file, "r") as f:
            filepaths.update([rel_path_from_s3uri(json.loads(l)["source-ref"]) for l in f])
    return filepaths


def select_examples(
    job_page_count,
    exclude_img_paths=set(),
    job_first_page_pct=0.4,
):

    with open("data/pages-all-sample.manifest.jsonl", "r") as fmanifest:
        examples_all = [json.loads(l) for l in fmanifest]

    # Separate and shuffle the first vs non-first pages:
    examples_all_arefirsts = [l["page-num"] == 1 for l in examples_all]

    examples_firsts = [e for ix, e in enumerate(examples_all) if examples_all_arefirsts[ix]]
    examples_nonfirsts = [e for ix, e in enumerate(examples_all) if not examples_all_arefirsts[ix]]
    random.Random(1337).shuffle(examples_firsts)
    random.Random(1337).shuffle(examples_nonfirsts)

    # Exclude already-annotated images:
    filtered_firsts = [
        e for e in examples_firsts if rel_path_from_s3uri(e["source-ref"]) not in exclude_img_paths
    ]
    filtered_nonfirsts = [
        e
        for e in examples_nonfirsts
        if rel_path_from_s3uri(e["source-ref"]) not in exclude_img_paths
    ]
    print(
        f"Excluded {len(examples_firsts) - len(filtered_firsts)} first and {len(examples_nonfirsts) - len(filtered_nonfirsts)} non-first pages"
    )

    # Draw from the filtered shuffled lists:
    n_first_pages = round(job_first_page_pct * job_page_count)
    n_nonfirst_pages = job_page_count - n_first_pages
    if n_first_pages > len(filtered_firsts):
        raise ValueError(
            "Unable to find enough first-page records to build manifest: Wanted "
            "{}, but only {} available from list after exclusions ({} before)".format(
                n_first_pages,
                len(filtered_firsts),
                len(examples_firsts),
            )
        )
    if n_nonfirst_pages > len(filtered_nonfirsts):
        raise ValueError(
            "Unable to find enough non-first-page records to build manifest: Wanted "
            "{}, but only {} available from list after exclusions ({} before)".format(
                n_nonfirst_pages,
                len(filtered_nonfirsts),
                len(examples_nonfirsts),
            )
        )
    print(f"Taking {n_first_pages} first pages and {n_nonfirst_pages} non-first pages.")
    selected = filtered_firsts[:n_first_pages] + filtered_nonfirsts[:n_nonfirst_pages]
    random.Random(1337).shuffle(selected)  # Shuffle again to avoid putting all 1stP at front
    return selected

# %% [markdown]
# To actually generate a new job input manifest, you just need to specify:
#
# - A unique name for the job
# - The number of examples (pages) you'll annotate
# - The ratio of first-pages to non-first pages (e.g. 0.4 -> 40% of examples will be the first page of a document)
#
# > ⚠️ **Warning:** If you've just completed an annotation job below, make sure you've `s3 sync`ed results back to the `data/annotations` folder - otherwise you'll set up a new job for the same pages again!

# %%
annotation_job_name = "cfpb-boxes-1"  # What will this job be called?
job_page_count = 20  # How many pages will we annotate?
job_first_page_pct = .4  # What proportion of pages should be first pages of a doc?


preannotated_img_paths = get_preannotated_imgs()
input_manifest_file = f"data/manifests/{annotation_job_name}.jsonl"
os.makedirs("data/manifests", exist_ok=True)
print(f"'{annotation_job_name}' saving to: {input_manifest_file}")
with open(input_manifest_file, "w") as f:
    for ix, example in enumerate(
        select_examples(
            job_page_count,
            exclude_img_paths=preannotated_img_paths,
            job_first_page_pct=job_first_page_pct,
        )
    ):
        if ix < 3:
            print(example)
        elif ix == 3:
            print("...")
        f.write(json.dumps(example) + "\n")

# %%
input_manifest_s3uri = f"s3://{bucket_name}/{bucket_prefix}{input_manifest_file}"
# !aws s3 cp $input_manifest_file $input_manifest_s3uri

# %% [markdown]
# ### Create the labelling job
#
# To minimize the risk of errors and get started quickly, you're recommended to create your labeling job by running the utility function provided below.
#
# This will set up a job with the default pre-built bounding box template (for faster annotation than the custom one we explored earlier):

# %%
print(f"Starting labeling job {annotation_job_name}\non data {input_manifest_s3uri}\n")
create_labeling_job_resp = util.smgt.create_bbox_labeling_job(
    annotation_job_name,
    bucket_name=bucket_name,
    execution_role_arn=role,
    fields=fields,
    input_manifest_s3uri=input_manifest_s3uri,
    output_s3uri=annotations_base_s3uri,
    workteam_arn=workteam_arn,
    # To create a review/adjustment job from a manifest with existing labels in:
    # reviewing_attribute_name="label",
    s3_inputs_prefix=f"{bucket_prefix}data/manifests",
)
print(f"\nLABELLING JOB STARTED:\n{create_labeling_job_resp['LabelingJobArn']}")

# %% [markdown]
# Alternatively, you can also explore creating the job through the [AWS Console for SageMaker Ground Truth](https://console.aws.amazon.com/sagemaker/groundtruth?#/labeling-jobs) (check your AWS Region!) by clicking on *Create labeling job*:
#
# - Leave (as default) the *label attribute name* the same as the *job name*
# - Select **Manual data setup** and use:
#   - The `input_manifest_s3uri` (`s3://[...].jsonl`) from above for the input location
#   - The `annotations_base_s3uri` (`s3://[...]/data/annotations`) with **no trailing slash** for the output location
# - Select or create any **SageMaker IAM execution role** that has access to the `bucket_name` we're using.
# - For **task type**, select *Image > Bounding Box*
# - On the second screen, be sure to use **worker type** *Private* and select the workteam we made earlier from the dropdown.
# - For the built-in task type, you'll need to enter the **labels** manually exactly in the order that we defined them in this notebook.
#
# The cell below prints out some of these values to help:

# %%
print(input_manifest_s3uri)
print(annotations_base_s3uri)
print(role)
print("\n".join(["\nLabels:", "-------"] + entity_classes))

# %% [markdown]
# ### Label the data!
#
# Now that the labeling job has been created, you'll see a new task for your user in the labeling portal (If you lost the portal link from your email, you can access it from the *Private* tab of the [SageMaker Ground Truth Workforces console](https://console.aws.amazon.com/sagemaker/groundtruth?#/labeling-workforces)).
#
# > ⏰ SageMaker Ground Truth processes the job data in batches, so it might take a minute or two for the job to appear in your list.
# >
# > If it's taking a long time, you can:
# >
# > - Double-check the job in the [Labeling jobs page of the Console](https://console.aws.amazon.com/sagemaker/groundtruth?#/labeling-jobs) to see if it's failed to start due to some error
# > - Check the job is set up for a workteam that you're a member of
# > - Check your user is showing as *Verified* and *Enabled* (i.e. that you completed the email verification successfully) in the *Private* tab of the [Workforces console](https://console.aws.amazon.com/sagemaker/groundtruth?#/labeling-workforces)
#
# ▶️ Click **Start working** and annotate the examples until the all are finished and you're returned to the portal homepage.
#
# ▶️ **Try to be as consistent as possible** in how you annotate the classes, because inconsistent annotations can significantly degrade final model accuracy. Refer to the guidance (in this notebook and the 'Full Instructions') that we applied when annotating the example set.
#
# ![](img/smgt-task-pending.png "Screenshot of SMGT labeling portal with pending task")

# %% [markdown]
# ### Sync the results locally (and iterate?)
#
# Once you've finished annotating and the job shows as "Complete" in the [SMGT Console](https://console.aws.amazon.com/sagemaker/groundtruth?#/labeling-jobs) (which **might take an extra minute or two**, while your annotations are consolidated), you can download the results here to the notebook via the cell below:

# %%
# !aws s3 sync --quiet $annotations_base_s3uri ./data/annotations

# %% [markdown]
# You should see a subfolder created with the name of your annotation job, under which the **`manifests/output/output.manifest`** file contains the consolidated results of your labelling - again in the open JSON-Lines format.
#
# ▶️ **Check** your results appear as expected, and explore the file format.
#
# > Because label outputs are in JSON-Lines, it's easy to consolidate, transform, and manipulate these results as required using open source tools!
#
# If you like, you can expand your dataset with **additional labelling jobs** by repeating these steps from [Collect a dataset](#Collect-a-dataset) down to here.
#
# > ⚠️ Take care to set a different `annotation_job_name` each time, as these must be unique.

# %% [markdown]
# ## Next Steps
#
# In this notebook we set up the modelling objective, collected the project dataset, and annotated (perhaps multiple) sets of training data.
#
# In the next, we'll consolidate these output manifests (together with some pre-prepared example data) and actually train/deploy our ML model.
#
# So you can now open up **notebook [2. Model Training.ipynb](2.%20Model%20Training.ipynb)**, and follow along!
